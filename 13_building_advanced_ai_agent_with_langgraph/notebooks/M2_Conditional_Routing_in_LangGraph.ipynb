# %% [markdown]
# # Conditional Routing in LangGraph
#
# In LangGraph, conditional routing allows the dynamic determination of the next node(s) to execute based on the current state.
#
# This is achieved using conditional edges, which evaluate a function using certain defined logic, to decide the subsequent path in the graph.
#
# This mechanism enables the creation of adaptable workflows that respond to varying conditions during execution. Let's dive deep into conditional routing in this demo.
#
# ![](https://i.imgur.com/uX12AyO.png)

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install langchain==0.3.14
# !pip install langgraph==0.2.66
# Out:
# Requirement already satisfied: langchain==0.3.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (3.13.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.3.63)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.3.8)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.1.147)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.12.4)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.22.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (3.11.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.14) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.14) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.3.1)
# Collecting langgraph==0.2.66
#   Using cached langgraph-0.2.66-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.66) (0.3.63)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.66) (2.1.2)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.66) (0.1.74)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (6.0.3)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (4.15.0)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (2.12.4)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph==0.2.66) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.66) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.66) (3.11.4)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.66) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.66) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.66) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.66) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.66) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.66) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.66) (1.3.1)
# Using cached langgraph-0.2.66-py3-none-any.whl (145 kB)
# Installing collected packages: langgraph
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 0.2.64
#     Uninstalling langgraph-0.2.64:
#       Successfully uninstalled langgraph-0.2.64
# Successfully installed langgraph-0.2.66

# %% [markdown]
# ## Creating the Graph with Conditional Edges
#
# [Edges](https://langchain-ai.github.io/langgraph/concepts/low_level/#edges) connect the nodes.
#
# Normal Edges are used if you want to *always* go from, for example, `node_1` to `node_2`.
#
# [Conditional Edges](https://langchain-ai.github.io/langgraph/reference/graphs/?h=conditional+edge#langgraph.graph.StateGraph.add_conditional_edges) are used want to *optionally* route between nodes.
#
# Conditional edges are implemented as functions that return the next node to visit based upon some logic.
#
# ![](https://i.imgur.com/uX12AyO.png)

# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
from IPython.display import Image, display

# Define the state structure
class State(TypedDict):
    weather: str

# Initialize the StateGraph
graph_builder = StateGraph(State)

# Define node functions
def weather_node(state: State) -> State:
    print("Checking the weather...")
    return state  # Just pass the state along

def rainy_node(state: State) -> State:
    print("It's rainy. Take an umbrella!")
    return state

def sunny_node(state: State) -> State:
    print("It's sunny. Wear sunglasses!")
    return state

# Define the routing function
def weather_routing(state: State) -> str:
    if state['weather'] == 'rainy':
        return "rainy" # name of the rainy node
    elif state['weather'] == 'sunny':
        return "sunny" # name of the sunny node
    else:
        raise ValueError("Invalid weather condition!")

# Add nodes to the graph
graph_builder.add_node("weather_node", weather_node)
graph_builder.add_node("rainy", rainy_node)
graph_builder.add_node("sunny", sunny_node)

# Define edges
graph_builder.add_edge(START, "weather_node")
graph_builder.add_conditional_edges("weather_node",
                                    # the routing function will route to the rainy node if weather state is 'rainy'
                                    # the routing function will route to the sunny node if the weather state is 'sunny'
                                    weather_routing, # routing function
                                    ["rainy", "sunny"] # possible nodes where the routing function can end up going
                                   )
graph_builder.add_edge("rainy", END)
graph_builder.add_edge("sunny", END)

# Compile the graph
graph = graph_builder.compile()

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Execute the graph with an initial state for "rainy"
print("\n--- Rainy Condition ---")
initial_state_rainy = {"weather": "rainy"}
result_rainy = graph.invoke(initial_state_rainy)
# Out:
# --- Rainy Condition ---
# Checking the weather...
# It's rainy. Take an umbrella!

# %%
# Execute the graph with an initial state for "sunny"
print("\n--- Sunny Condition ---")
initial_state_sunny = {"weather": "sunny"}
result_sunny = graph.invoke(initial_state_sunny)
# Out:
# --- Sunny Condition ---
# Checking the weather...
# It's sunny. Wear sunglasses!

# %%
# Execute the graph with an initial state for "sunny"
print("\n--- Sunny Condition ---")
initial_state_sunny = {"weather": "humid"}
result_sunny = graph.invoke(initial_state_sunny)
# Out:
# --- Sunny Condition ---
# Checking the weather...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 print("\n--- Sunny Condition ---")
#       3 initial_state_sunny = {"weather": "humid"}
# ----> 4 result_sunny = graph.invoke(initial_state_sunny)
#
# File ~/yes/envs/notebooks/lib/python3.13/site-packages/langgraph/pregel/__init__.py:1961, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1959 else:
#    1960     chunks = []
# -> 1961 for chunk in self.stream(
#    1962     input,
#    1963     config,
#    1964     stream_mode=stream_mode,
#    1965     output_keys=output_keys,
#    1966     interrupt_before=interrupt_before,
#    1967     interrupt_after=interrupt_after,
#    1968     debug=debug,
#    1969     **kwargs,
#    1970 ):
#    1971     if stream_mode == "values":
#    1972         latest = chunk
#
# File ~/yes/envs/notebooks/lib/python3.13/site-packages/langgraph/pregel/__init__.py:1670, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1664     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1665     # computation proceeds in steps, while there are channel updates.
#    1666     # Channel updates from step N are only visible in step N+1
#    1667     # channels are guaranteed to be immutable for the duration of the step,
#    1668     # with channel updates applied only at the transition between steps.
#    1669     while loop.tick(input_keys=self.input_channels):
# -> 1670         for _ in runner.tick(
#    1671             loop.tasks.values(),
#    1672             timeout=self.step_timeout,
#    1673             retry_policy=self.retry_policy,
#    1674             get_waiter=get_waiter,
#    1675         ):
#    1676             # emit output
#    1677             yield from output()
#    1678 # emit output
#
# File ~/yes/envs/notebooks/lib/python3.13/site-packages/langgraph/pregel/runner.py:231, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     229 t = tasks[0]
#     230 try:
# --> 231     run_with_retry(
#     232         t,
#     233         retry_policy,
#     234         configurable={
#     235             CONFIG_KEY_SEND: partial(writer, t),
#     236             CONFIG_KEY_CALL: partial(call, t),
#     237         },
#     238     )
#     239     self.commit(t, None)
#     240 except Exception as exc:
#
# File ~/yes/envs/notebooks/lib/python3.13/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/yes/envs/notebooks/lib/python3.13/site-packages/langgraph/utils/runnable.py:464, in RunnableSeq.invoke(self, input, config, **kwargs)
#     462             input = step.invoke(input, config, **kwargs)
#     463         else:
# --> 464             input = step.invoke(input, config)
#     465 # finish the root run
#     466 except BaseException as e:
#
# File ~/yes/envs/notebooks/lib/python3.13/site-packages/langgraph/utils/runnable.py:226, in RunnableCallable.invoke(self, input, config, **kwargs)
#     224 else:
#     225     context.run(_set_config_context, config)
# --> 226     ret = context.run(self.func, *args, **kwargs)
#     227 if isinstance(ret, Runnable) and self.recurse:
#     228     return ret.invoke(input, config)
#
# File ~/yes/envs/notebooks/lib/python3.13/site-packages/langgraph/graph/graph.py:95, in Branch._route(self, input, config, reader, writer)
#      93 else:
#      94     value = input
# ---> 95 result = self.path.invoke(value, config)
#      96 return self._finish(writer, input, result, config)
#
# File ~/yes/envs/notebooks/lib/python3.13/site-packages/langgraph/utils/runnable.py:218, in RunnableCallable.invoke(self, input, config, **kwargs)
#     216     context = copy_context()
#     217     context.run(_set_config_context, child_config)
# --> 218     ret = context.run(self.func, *args, **kwargs)
#     219 except BaseException as e:
#     220     run_manager.on_chain_error(e)
#
# Cell In[2], line 32, in weather_routing(state)
#      30     return "sunny" # name of the sunny node
#      31 else:
# ---> 32     raise ValueError("Invalid weather condition!")
#
# ValueError: Invalid weather condition!
# During task with name 'weather_node' and id '2f4cd369-81d6-b105-3526-602893ed92a6'

# %% [markdown]
# ## Conditional Routing with More Nodes
#
# The more nodes you have for custom logic you just need to define the node functions and then put in relevant conditions for the function which would do the conditional routing as shown in the example below.
#
# ![](https://i.imgur.com/uvZeLV3.png)

# %%
from typing import Annotated
from langgraph.graph.message import add_messages

class State(TypedDict):
    messages: Annotated[list, add_messages]
    topic: str


def get_topic(state: State) -> str:
    topic = state['messages'][0].content
    print(f"---Getting topic: {topic}---")
    return {"topic": topic}

def decide_route(state: State) -> State:
    print("---Conditional Routing---")
    topic = state['topic']
    print(topic)
    if topic.lower() in ['batman', 'superman']:
        return "node_dc"
    if topic.lower() in ['spiderman', 'avengers']:
        return "node_marvel"
    return "node_others"

def node_dc(state):
    print("---Node DC Comics---")
    topic = state['topic']
    return {"messages": "Hello yes happy to show you comics of: "+topic}

def node_marvel(state):
    print("---Node Marvel Comics---")
    topic = state['topic']
    return {"messages": "Hello yes happy to show you comics of: "+topic}

def node_others(state):
    print("---Node Others---")
    topic = state['topic']
    return {"messages": "Sorry we do not have: "+topic}


# Build graph
builder = StateGraph(State)
builder.add_node("get_topic", get_topic)
builder.add_node("node_dc", node_dc)
builder.add_node("node_marvel", node_marvel)
builder.add_node("node_others", node_others)

# Logic
builder.add_edge(START, "get_topic")
builder.add_conditional_edges("get_topic",
                              decide_route,
                              ["node_dc", "node_marvel", "node_others"]
                              )
builder.add_edge("node_dc", END)
builder.add_edge("node_marvel", END)
builder.add_edge("node_others", END)


# Add
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
def call_agent(agent, topic):
    msgs = agent.invoke({"messages": topic})
    print(msgs['messages'][-1].content)

# %%
call_agent(graph, "Batman")
# Out:
# ---Getting topic: Batman---
# ---Conditional Routing---
# Batman
# ---Node DC Comics---
# Hello yes happy to show you comics of: Batman

# %%
call_agent(graph, "avengers")
# Out:
# ---Getting topic: avengers---
# ---Conditional Routing---
# avengers
# ---Node Marvel Comics---
# Hello yes happy to show you comics of: avengers

# %%
call_agent(graph, "Venom")
# Out:
# ---Getting topic: Venom---
# ---Conditional Routing---
# Venom
# ---Node Others---
# Sorry we do not have: Venom
