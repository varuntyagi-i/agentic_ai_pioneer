# %% [markdown]
# # Build a Planning Agent for Deep Research & Structured Report Generation with LangGraph
#
# ### IMPORTANT: Be Careful this Agent will do a lot of searches so if you run it too many times you can easily exhaust your API limits for Tavily Search if you are on the free tier
#
# In this project we will be building a Planning Agent for Deep Research and Structured Report Generation in the form of Wiki-style Reports (structured with key sections and section headings)
#
#
# ![](https://i.imgur.com/STSC73k.png)
#
#
# ### Planning Agent for Deep Research and Structured Report Generation
#
# This project focuses on building a **Planning Agent for Deep Research and Structured Report Generation**. The agent automates the process of analyzing a user-defined topic, performing web research, and generating a well-structured report. The workflow includes the following components:
#
# 1. **Report Planning**:
#    - The agent analyzes the user-provided **topic** and **default report template** to create a custom plan for the report.
#    - Sections such as **Introduction**, **Key Sections**, and **Conclusion** are defined based on the topic.
#    - A **web search tool** is used to collect information required before deciding the main sections.
#
# 2. **Parallel Execution for Research and Writing**:
#    - The agent uses **parallel execution** to efficiently perform:
#      - **Web Research**: Queries are generated for each section and executed via the web search tool to retrieve up-to-date information.
#      - **Section Writing**: The retrieved data is used to write content for each section, with the following process:
#        - The **Researcher** gathers relevant data from the web.
#        - The **Section Writer** uses the data to generate structured content for the assigned section.
#
# 3. **Formatting Completed Sections**:
#    - Once all sections are written, they are formatted to ensure consistency and adherence to the report structure.
#
# 4. **Introduction and Conclusion Writing**:
#    - After the main sections are completed and formatted:
#      - The **Introduction** and **Conclusion** are written based on the content of the remaining sections (in parallel)
#      - This process ensures that these sections align with the overall flow and insights of the report.
#
# 5. **Final Compilation**:
#    - All completed sections are compiled together to generate the **final report**.
#    - The final output is a comprehensive and structured document in the style of wiki docs.

# %% [markdown]
# ## Install OpenAI, LangGraph and LangChain dependencies

# %%
# !pip install langchain==0.3.14
# !pip install langchain-openai==0.3.0
# !pip install langchain-community==0.3.14
# !pip install langgraph==0.2.64
# !pip install rich
# Out:
# Requirement already satisfied: langchain==0.3.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (3.13.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.3.63)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.3.8)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.1.147)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.12.4)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.22.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (3.11.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.14) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.14) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.3.1)
# Requirement already satisfied: langchain-openai==0.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.3.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-openai==0.3.0) (0.3.63)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-openai==0.3.0) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-openai==0.3.0) (0.12.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (6.0.3)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (4.15.0)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2.12.4)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (3.11.4)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.0) (0.12.0)
# Requirement already satisfied: sniffio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.0) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2.3.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.0) (2025.11.3)
# Requirement already satisfied: langchain-community==0.3.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.4.3)
# Requirement already satisfied: langchain<0.4.0,>=0.3.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.3.14)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.3.63)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.1.147)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (2.11.0)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community==0.3.14) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community==0.3.14) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community==0.3.14) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain-community==0.3.14) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (3.11.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.14) (1.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.14) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.14) (2.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (1.3.1)
# Requirement already satisfied: langgraph==0.2.64 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.2.64)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.64) (0.3.63)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.64) (2.1.2)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.64) (0.1.74)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (6.0.3)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (4.15.0)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (2.12.4)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph==0.2.64) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (3.11.4)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (1.3.1)
# Requirement already satisfied: rich in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from rich) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)

# %% [markdown]
# ## Enter Open AI API Key

# %%
from getpass import getpass

OPENAI_KEY = getpass('Enter Open AI API Key: ')

# %% [markdown]
# ## Enter Tavily Search API Key
#
# Get a free API key from [here](https://tavily.com/#api)

# %%
TAVILY_API_KEY = getpass('Enter Tavily Search API Key: ')

# %% [markdown]
# ## Setup Environment Variables

# %%
import os

os.environ['OPENAI_API_KEY'] = OPENAI_KEY
os.environ['TAVILY_API_KEY'] = TAVILY_API_KEY

# %% [markdown]
# ## Define Agent State Schema
#
# Each specific set of operations (nodes) will have their own schema as defined below. You can customize this further based on your own style of report generation

# %%
from typing_extensions import TypedDict
from pydantic import BaseModel, Field
import operator
from typing import  Annotated, List, Optional, Literal

class Section(BaseModel):
    name: str = Field(
        description="Name for a particular section of the report.",
    )
    description: str = Field(
        description="Brief overview of the main topics and concepts to be covered in this section.",
    )
    research: bool = Field(
        description="Whether to perform web search for this section of the report."
    )
    content: str = Field(
        description="The content for this section."
    )

class Sections(BaseModel):
    sections: List[Section] = Field(
        description="All the Sections of the overall report.",
    )

class SearchQuery(BaseModel):
    search_query: str = Field(None, description="Query for web search.")

class Queries(BaseModel):
    queries: List[SearchQuery] = Field(
        description="List of web search queries.",
    )

class ReportStateInput(TypedDict):
    topic: str # Report topic

class ReportStateOutput(TypedDict):
    final_report: str # Final report

class ReportState(TypedDict):
    topic: str # Report topic
    sections: list[Section] # List of report sections
    completed_sections: Annotated[list, operator.add] # Send() API
    report_sections_from_research: str # String of any completed sections from research to write final sections
    final_report: str # Final report

class SectionState(TypedDict):
    section: Section # Report section
    search_queries: list[SearchQuery] # List of search queries
    source_str: str # String of formatted source content from web search
    report_sections_from_research: str # String of any completed sections from research to write final sections
    completed_sections: list[Section] # Final key we duplicate in outer state for Send() API

class SectionOutputState(TypedDict):
    completed_sections: list[Section] # Final key we duplicate in outer state for Send() API

# %% [markdown]
# ## Utility Functions
#
# - __`run_search_queries(...)`__ : This will asynchronously run tavily search queries for specific list of queries and return back the search results. This is async so it is non blocking and can be executed in parallel.

# %%
from langchain_community.utilities.tavily_search import TavilySearchAPIWrapper
import asyncio
from dataclasses import asdict, dataclass
from typing import Dict, Any, List, Union


# just to handle objects created from LLM reponses
@dataclass
class SearchQuery:
    search_query: str

    def to_dict(self) -> Dict[str, Any]:
        return asdict(self)


tavily_search = TavilySearchAPIWrapper()


async def run_search_queries(
    search_queries: List[Union[str, SearchQuery]],
    num_results: int = 5,
    include_raw_content: bool = False
) -> List[Dict]:

    search_tasks = []

    for query in search_queries:
        # Handle both string and SearchQuery objects
        # Just in case LLM fails to generate queries as:
        # class SearchQuery(BaseModel):
        #     search_query: str
        query_str = query.search_query if isinstance(query, SearchQuery) else str(query) # text query

        try:
            # get results from tavily asynchronously (in parallel) for each search query
            search_tasks.append(
                tavily_search.raw_results_async(
                    query=query_str,
                    max_results=num_results,
                    search_depth='advanced',
                    include_answer=False,
                    include_raw_content=include_raw_content
                )
            )
        except Exception as e:
            print(f"Error creating search task for query '{query_str}': {e}")
            continue

    # Execute all searches concurrently and await results
    try:
        if not search_tasks:
            return []
        search_docs = await asyncio.gather(*search_tasks, return_exceptions=True)
        # Filter out any exceptions from the results
        valid_results = [
            doc for doc in search_docs
            if not isinstance(doc, Exception)
        ]
        return valid_results
    except Exception as e:
        print(f"Error during search queries: {e}")
        return []

# %% [markdown]
# - __`format_search_query_results(...)`__ : This will extract the context from tavily search results, make sure content is not duplicated from same urls and format it to show the Source, URL, relevant content (and optionally raw content which can be truncated based on number of tokens)

# %%
import tiktoken
from typing import List, Dict, Union, Any

def format_search_query_results(
    search_response: Union[Dict[str, Any], List[Any]],
    max_tokens: int = 2000,
    include_raw_content: bool = False
) -> str:
    encoding = tiktoken.encoding_for_model("gpt-4")
    sources_list = []

    # Handle different response formats
    # if search results is a dict
    if isinstance(search_response, dict):
        if 'results' in search_response:
            sources_list.extend(search_response['results'])
        else:
            sources_list.append(search_response)
    # if search results is a list
    elif isinstance(search_response, list):
        for response in search_response:
            if isinstance(response, dict):
                if 'results' in response:
                    sources_list.extend(response['results'])
                else:
                    sources_list.append(response)
            elif isinstance(response, list):
                sources_list.extend(response)

    if not sources_list:
        return "No search results found."

    # Deduplicate by URL and keep unique sources (website urls)
    unique_sources = {}
    for source in sources_list:
        if isinstance(source, dict) and 'url' in source:
            if source['url'] not in unique_sources:
                unique_sources[source['url']] = source

    # Format output
    formatted_text = "Content from web search:\n\n"
    for i, source in enumerate(unique_sources.values(), 1):
        formatted_text += f"Source {source.get('title', 'Untitled')}:\n===\n"
        formatted_text += f"URL: {source['url']}\n===\n"
        formatted_text += f"Most relevant content from source: {source.get('content', 'No content available')}\n===\n"

        if include_raw_content:
            # truncate raw webpage content to a certain number of tokens to prevent exceeding LLM max token window
            raw_content = source.get("raw_content", "")
            if raw_content:
                tokens = encoding.encode(raw_content)
                truncated_tokens = tokens[:max_tokens]
                truncated_content = encoding.decode(truncated_tokens)
                formatted_text += f"Raw Content: {truncated_content}\n\n"

    return formatted_text.strip()

# %% [markdown]
# ## Test Sample Utility Functions

# %%
docs = await run_search_queries(['langgraph'], include_raw_content=True)
docs
# Out:
# [{'query': 'langgraph',
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'url': 'https://www.geeksforgeeks.org/machine-learning/what-is-langgraph/',
#     'title': 'What is LangGraph? - GeeksforGeeks',
#     'content': '# What is LangGraph?\n\nLast Updated : \n10 Oct, 2025\n\nSuggest changes\n\n1 Likes\n\nLangGraph is an open-source framework built by LangChain that streamlines the creation and management of AI agent workflows. At its core, LangGraph combines large language models (LLMs) with graph-based architectures allowing developers to map, organize and optimize how AI agents interact and make decisions.',
#     'score': 0.9345448,
#     'raw_content': '# What is LangGraph?\n\nLast Updated : \n10 Oct, 2025\n\nSuggest changes\n\n1 Likes\n\nLangGraph is an open-source framework built by [LangChain](https://www.geeksforgeeks.org/artificial-intelligence/introduction-to-langchain/) that streamlines the creation and management of AI agent workflows. At its core, LangGraph combines large language models (LLMs) with graph-based architectures allowing developers to map, organize and optimize how AI agents interact and make decisions.\n\nBy treating workflows as interconnected nodes and edges, LangGraph offers a scalable, transparent and developer-friendly way to design advanced AI systems ranging from simple chatbots to multi-agent system.\n\n## Workflow of LangGraph\n\nThe diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.\n\nHere\'s a step-by-step interpretation of the flow:\n\n1. ****Start:**** The process begins with the agent (Assistant) initiating an interaction or task.\n2. ****Assistant:**** This is the central node managing the overall workflow. It controls the movement between tools and sequences based on the current state.\n3. ****Enter Write Sequence:**** If the task requires writing assistance like generating content, the workflow enters a dedicated writing sequence.\n4. ****Write Assistant:**** This specialized module focuses on the writing process. It may loop with tools for refining or editing before completing the sequence.\n5. ****Leave Write Sequence:**** Once the writing task is complete the system exits the write mode.\n6. ****Writer Sensitive Tools & Assistant Tools:**** These nodes provide specialized capabilities. Depending on the state the Assistant routes tasks to tools that enhance writing or perform sensitive operations.\n7. ****End:**** The process concludes once the desired outcome is achieved and all necessary tools have been executed.\n\n## Components of LangGraph\n\nThese core components work together smoothly to help developers build, customize and manage complex AI-driven workflows.\n\n* ****Monitoring mechanism:**** Human-in-the-loop (HITL) ensures humans remain part of the decision-making process. It improves machine learning accuracy by using critical data points instead of relying on random sampling.\n* ****Stateful graphs:**** Each node represents a step in computation and carries forward information from previous steps. This enables continuous, contextual processing of data throughout the workflow.\n* ****Cyclical graphs:**** Graphs that contain loops is used for workflows where certain steps may repeat. It becomes important for complex agent run-times.\n* ****Nodes:**** The individual components or agents within a workflow is called node. They act like “actors” performing tasks or calling tools (e.g., a ToolNode for tool integration).\n* ****Edges:**** Edges determine which node should run next. They can follow fixed paths or branching conditions based on the system state.\n* ****RAG (Retrieval-Augmented Generation):**** [RAG](https://www.geeksforgeeks.org/nlp/what-is-retrieval-augmented-generation-rag/) enhances LLMs by adding relevant external documents as context, improving the accuracy and richness of outputs.\n* ****Workflows:**** Sequences of interactions between nodes. By designing workflows, users combine multiple nodes into powerful, dynamic AI processes.\n* ****APIs:**** A set of tools to programmatically add nodes, modify workflows or extract data. Offers developers flexibility and seamless integration with other systems.\n* ****LangSmith:**** [LangSmith](https://www.geeksforgeeks.org/nlp/introduction-to-langsmith/) is a dedicated API for managing large language models (LLMs). Provides functions for initializing LLMs, creating conditional logic and optimizing performance.\n\n## How LangGraph Scales\n\n* ****Graph-based architecture:**** Ensures AI workflows grow without slowing down or losing efficiency.\n* ****Enhanced decision-making:**** Models relationships  ...
#    {'url': 'https://docs.langchain.com/oss/python/langgraph/overview',
#     'title': 'LangGraph overview - Docs by LangChain',
#     'content': 'Trusted by companies shaping the future of agents— including Klarna, Replit, Elastic, and more— LangGraph is a low-level orchestration framework and runtime for building, managing, and deploying long-running, stateful agents.LangGraph is very low-level, and focused entirely on agent orchestration. Before using LangGraph, we recommend you familiarize yourself with some of the components used to build agents, starting with models and tools.We will commonly use LangChain components throughout the',
#     'score': 0.9314689,
#     'raw_content': 'LangGraph overview - Docs by LangChain\n\n===============\n\n[Skip to main content](https://docs.langchain.com/oss/python/langgraph/overview#content-area)\n\n[Docs by LangChain home page![Image 1: light logo](https://mintcdn.com/langchain-5e9cc07a/Xbr8HuVd9jPi6qTU/images/brand/langchain-docs-teal.svg?fit=max&auto=format&n=Xbr8HuVd9jPi6qTU&q=85&s=16111530672bf976cb54ef2143478342)![Image 2: dark logo](https://mintcdn.com/langchain-5e9cc07a/Xbr8HuVd9jPi6qTU/images/brand/langchain-docs-lilac.svg?fit=max&auto=format&n=Xbr8HuVd9jPi6qTU&q=85&s=b70fb1a2208670492ef94aef14b680be)](https://docs.langchain.com/)LangChain + LangGraph\n\nSearch...\n\nCtrl K\n\n*   [GitHub](https://github.com/langchain-ai)\n*   [Try LangSmith](https://smith.langchain.com/)\n*   [Try LangSmith](https://smith.langchain.com/)\n\nSearch...\n\nNavigation\n\nLangGraph overview\n\n[LangChain](https://docs.langchain.com/oss/python/langchain/overview)[LangGraph](https://docs.langchain.com/oss/python/langgraph/overview)[Deep Agents](https://docs.langchain.com/oss/python/deepagents/overview)[Integrations](https://docs.langchain.com/oss/python/integrations/providers/overview)[Learn](https://docs.langchain.com/oss/python/learn)[Reference](https://docs.langchain.com/oss/python/reference/overview)[Contribute](https://docs.langchain.com/oss/python/contributing/overview)\n\nPython\n\n*   [Overview](https://docs.langchain.com/oss/python/langgraph/overview)\n\n##### LangGraph v1.0\n\n*   [Release notes](https://docs.langchain.com/oss/python/releases/langgraph-v1)\n*   [Migration guide](https://docs.langchain.com/oss/python/migrate/langgraph-v1)\n\n##### Get started\n\n*   [Install](https://docs.langchain.com/oss/python/langgraph/install)\n*   [Quickstart](https://docs.langchain.com/oss/python/langgraph/quickstart)\n*   [Local server](https://docs.langchain.com/oss/python/langgraph/local-server)\n*   [Thinking in LangGraph](https://docs.langchain.com/oss/python/langgraph/thinking-in-langgraph)\n*   [Workflows + agents](https://docs.langchain.com/oss/python/langgraph/workflows-agents)\n\n##### Capabilities\n\n*   [Persistence](https://docs.langchain.com/oss/python/langgraph/persistence)\n*   [Durable execution](https://docs.langchain.com/oss/python/langgraph/durable-execution)\n*   [Streaming](https://docs.langchain.com/oss/python/langgraph/streaming)\n*   [Interrupts](https://docs.langchain.com/oss/python/langgraph/interrupts)\n*   [Time travel](https://docs.langchain.com/oss/python/langgraph/use-time-travel)\n*   [Memory](https://docs.langchain.com/oss/python/langgraph/add-memory)\n*   [Subgraphs](https://docs.langchain.com/oss/python/langgraph/use-subgraphs)\n\n##### Production\n\n*   [Application structure](https://docs.langchain.com/oss/python/langgraph/application-structure)\n*   [Studio](https://docs.langchain.com/oss/python/langgraph/studio)\n*   [Test](https://docs.langchain.com/oss/python/langgraph/test)\n*   [Deploy](https://docs.langchain.com/oss/python/langgraph/deploy)\n*   [Agent Chat UI](https://docs.langchain.com/oss/python/langgraph/ui)\n*   [Observability](https://docs.langchain.com/oss/python/langgraph/observability)\n\n##### LangGraph APIs\n\n*   Graph API \n*   Functional API \n*   [Runtime](https://docs.langchain.com/oss/python/langgraph/pregel)\n\nOn this page\n*   [Install](https://docs.langchain.com/oss/python/langgraph/overview#install)\n*   [Core benefits](https://docs.langchain.com/oss/python/langgraph/overview#core-benefits)\n*   [LangGraph ecosystem](https://docs.langchain.com/oss/python/langgraph/overview#langgraph-ecosystem)\n*   [Acknowledgements](https://docs.langchain.com/oss/python/langgraph/overview#acknowledgements)\n\nLangGraph overview\n==================\n\nCopy page\n\nCopy page\n\n**LangGraph v1.0 is now available!**For a complete list of changes and instructions on how to upgrade your code, see the [release notes](https://docs.langchain.com/oss/python/releases/langgraph-v1) and [migration guide](https://docs.langcha ...
#    {'url': 'https://gunjanvi.medium.com/langgraph-part-1-dd37e2936ca9',
#     'title': 'LangGraph — Part 1 - Gunjan - Medium',
#     'content': 'Sitemap\n\nOpen in app\n\nSign in\n\nWrite\n\nSearch\n\nSign in\n\n# LangGraph — Part 1\n\nGunjan\n\n3 min read\n\n·\n\nSep 2, 2024\n\n--\n\nLangGraph is a library that enables building and managing directed acyclic graphs (DAGs) in the context of natural language processing (NLP). It is designed to help in constructing complex workflows where each node in the graph represents a computational step, often involving language models or other NLP-related tasks.\n\nHow is different from Langchain ?',
#     'score': 0.91795975,
#     'raw_content': '[Sitemap](/sitemap/sitemap.xml)\n\n[Open in app](https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2Fdd37e2936ca9&%7Efeature=LoOpenInAppButton&%7Echannel=ShowPostUnderUser&%7Estage=mobileNavBar&source=post_page---top_nav_layout_nav-----------------------------------------)\n\n[Sign in](https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fgunjanvi.medium.com%2Flanggraph-part-1-dd37e2936ca9&source=post_page---top_nav_layout_nav-----------------------global_nav------------------)\n\n[Write](https://medium.com/m/signin?operation=register&redirect=https%3A%2F%2Fmedium.com%2Fnew-story&source=---top_nav_layout_nav-----------------------new_post_topnav------------------)\n\n[Search](https://medium.com/search?source=post_page---top_nav_layout_nav-----------------------------------------)\n\n[Sign in](https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fgunjanvi.medium.com%2Flanggraph-part-1-dd37e2936ca9&source=post_page---top_nav_layout_nav-----------------------global_nav------------------)\n\n# LangGraph — Part 1\n\n[Gunjan](/?source=post_page---byline--dd37e2936ca9---------------------------------------)\n\n3 min read\n\n·\n\nSep 2, 2024\n\n--\n\nLangGraph is a library that enables building and managing directed acyclic graphs (DAGs) in the context of natural language processing (NLP). It is designed to help in constructing **complex workflows** where each node in the graph represents a computational step, often involving language models or other NLP-related tasks.\n\nHow is different from Langchain ?\n\n* **LangGraph** allows for the creation of both linear and cyclic workflows, offering greater flexibility for complex or iterative processes.\n* **LangChain (with LCEL)** is more suited for linear workflows or state machines, where each step follows a sequential path without revisiting previous steps, making it less suited for workflows that require cycles.\n\n## Core Components\n\n### Nodes\n\nNodes in LangGraph are individual tasks or steps within a workflow, each representing a specific computation or operation that processes data. They are connected by edges, which define dependencies, allowing for the sequential or parallel execution of tasks based on the graph’s structure.\n\n### Edges\n\nEdges in LangGraph represent the dependencies between nodes, defining the order in which tasks should be executed. They ensure that a node only processes data after its prerequisite nodes have completed, allowing for controlled, sequential, or parallel execution within the workflow.\n\n### Conditional Edges\n\nConditional edges in LangGraph are specialized edges that dictate the execution of a node based on the outcome or conditions of its preceding nodes. They enable dynamic workflows, where a node only executes if specific criteria or conditions are met, allowing for more flexible and adaptive processing.\n\n### State Schemas\n\nState Schemas in LangGraph define the possible states a node or process can be in during its execution, along with the transitions between these states based on specific conditions or events. They help manage the flow of a workflow by outlining how and when a node can move from one state to another, ensuring structured and controlled execution within the graph.\n\n### Reducers\n\nReducers in LangGraph are functions that aggregate or combine data from multiple nodes or steps in a workflow. They are used to process and condense the output from various sources into a single result, often playing a crucial role in summarizing or merging data as it moves through the workflow.\n\n### Cyclic Graph\n\nA cyclic graph in LangGraph refers to a graph structure where nodes are connected in such a way that it’s possible to return to the starting node, creating loops or cycles. This allows for iterative processes or repeated execution of certain tasks within the workflow, enabling more complex and dynamic behavior compared to a standard directed acyclic graph (DAG) ...
#    {'url': 'https://www.datacamp.com/tutorial/langgraph-tutorial',
#     'title': 'LangGraph Tutorial: What Is LangGraph and How to Use It?',
#     'content': "Imagine you're building a complex, multi-agent large language model (LLM) application. It's exciting, but it comes with challenges: managing the state of various agents, coordinating their interactions, and handling errors effectively. This is where LangGraph can help.\n\nLangGraph is a library within the LangChain ecosystem designed to tackle these challenges head-on. LangGraph provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured manner. [...] Skip to main content\n\n# LangGraph Tutorial: What Is LangGraph and How to Use It?\n\nLangGraph is a library within the LangChain ecosystem that provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured and efficient manner.\n\nJun 26, 2024  · 12 min read [...] For applications requiring autonomous decision-making, LangGraph enables the creation of agents that can perform tasks independently based on user inputs and predefined logic.\n\nThese agents can execute complex workflows, interact with other systems, and adapt to new information dynamically. LangGraph's structured framework ensures that each agent operates efficiently and effectively, making it suitable for tasks like automated customer support, data processing, and system monitoring.",
#     'score': 0.91399205,
#     'raw_content': '[Skip to main content](#main)\n\n# LangGraph Tutorial: What Is LangGraph and How to Use It?\n\nLangGraph is a library within the LangChain ecosystem that provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured and efficient manner.\n\nJun 26, 2024 \xa0· 12 min read\n\nImagine you\'re building a complex, multi-agent large language model (LLM) application. It\'s exciting, but it comes with challenges: managing the state of various agents, coordinating their interactions, and handling errors effectively. This is where LangGraph can help.\n\nLangGraph is a library within the LangChain ecosystem designed to tackle these challenges head-on. LangGraph provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured manner.\n\nIt simplifies the development process by enabling the creation of cyclical graphs, which are essential for developing agent runtimes. With LangGraph, we can easily build robust, scalable, and flexible multi-agent systems.\n\nIf you want to learn more about the LangChain ecosystem, I recommend this [introduction to LangChain](https://www.datacamp.com/tutorial/introduction-to-langchain-for-data-engineering-and-data-applications). You can also check out our [LangGraph video tutorial](https://www.youtube.com/watch?v=UklCxmEvz2w) below.\n\n## What Is LangGraph?\n\nLangGraph enables us to create stateful, multi-actor applications utilizing LLMs as easily as possible. It extends the capabilities of LangChain, introducing the ability to create and manage cyclical graphs, which are pivotal for developing sophisticated agent runtimes. The core concepts of LangGraph include: graph structure, state management, and coordination.\n\n### Graph structure\n\nImagine your application as a directed graph. In LangGraph, each node represents an LLM agent, and the edges are the communication channels between these agents. This structure allows for clear and manageable workflows, where each agent performs specific tasks and passes information to other agents as needed.\n\n### State management\n\nOne of LangGraph\'s standout features is its automatic state management. This feature enables us to track and persist information across multiple interactions. As agents perform their tasks, the state is dynamically updated, ensuring the system maintains context and responds appropriately to new inputs.\n\n### Coordination\n\nLangGraph ensures agents execute in the correct order and that necessary information is exchanged seamlessly. This coordination is vital for complex applications where multiple agents need to work together to achieve a common goal. By managing the flow of data and the sequence of operations, LangGraph allows developers to focus on the high-level logic of their applications rather than the intricacies of agent coordination.\n\n## Why LangGraph?\n\nAs I mentioned above, LangGraph offers several significant advantages for developers working with complex LLM applications. Here are some of the real-world benefits LangGraph offers.\n\n### Simplified development\n\nLangGraph abstracts away the complexities associated with state management and agent coordination. This means developers can define their workflows and logic without worrying about the underlying mechanisms that ensure data consistency and proper execution order. This simplification accelerates the development process and reduces the likelihood of errors. It’s a game-changer!\n\n### Flexibility\n\nWith LangGraph, developers have the flexibility to define their own agent logic and communication protocols. This allows for highly customized applications tailored to specific use cases. Whether you need a chatbot that can handle various types of user requests or a multi-agent system that performs complex tasks, LangGraph provides the tools to build exactly what you need. It’s all about giving you the power to create.\n\n### Scalability\n\nLangGraph is bu ...
#    {'url': 'https://arxiv.org/html/2412.03801v1',
#     'title': 'Agent AI with LangGraph: A Modular Framework for Enhancing ...',
#     'content': 'As shown in Figure 3, LangGraph is a framework for building agents, allowing developers to create complex workflows by defining states, nodes, and edges. This paper implements a multilingual translation system that can automatically select the appropriate translation agent to translate the text based on the input text that requires translation. The IntentAgent is responsible for parsing the input text and intent, and selecting the suitable translation agent according to the predefined mapping [...] LangChain is an application development framework powered by Large Language Models (LLMs), offering open-source building blocks, components, and third-party integrations that enable developers to construct applications. LangGraph is a framework built upon LangChain, simplifying the creation and management of agents and their runtime environments. In the application of machine translation, LangGraph, through its state management system, allows agents to maintain dialogue and remember contextual [...] machine translation tasks. LangGraph, as a graph-based framework, offers a flexible and efficient way to construct agents that can leverage the capabilities of large language models to perform complex tasks, achieving high-quality machine translation. The research presented in this paper not only provides a new technological path for the field of machine translation but also serves as a reference for other application areas that require complex language understanding and generation',
#     'score': 0.902687,
#     'raw_content': '11institutetext:  Executive Vice President,Ferret Relationship Intelligence   \nBurlingame, CA 94010, USA   \n11email: jialinwangspace@gmail.com   \n<https://www.linkedin.com/in/starspacenlp/> 22institutetext: Intelligent Cloud Network Monitoring Department   \nChina Telecom Shanghai Company,Shanghai, China   \n22email: duanzh.sh@chinatelecom.cn   \n\n# Agent AI with LangGraph: A Modular Framework for Enhancing Machine Translation Using Large Language Models\n\nJialin Wang 11 \u2003\u2003 Zhihua Duan 2 2\n\n###### Abstract\n\nThis paper explores the transformative role of Agent AI and LangGraph in advancing the automation and effectiveness of machine translation (MT). Agents are modular components designed to perform specific tasks, such as translating between particular languages, with specializations like TranslateEnAgent, TranslateFrenchAgent, and TranslateJpAgent for English, French, and Japanese translations, respectively. These agents leverage the powerful semantic capabilities of large language models (LLMs), such as GPT-4o, to ensure accurate, contextually relevant translations while maintaining modularity, scalability, and context retention.\n\nLangGraph, a graph-based framework built on LangChain, simplifies the creation and management of these agents and their workflows. It supports dynamic state management, enabling agents to maintain dialogue context and automates complex workflows by linking agents and facilitating their collaboration. With flexibility, open-source community support, and seamless integration with LLMs, LangGraph empowers agents to deliver high-quality translations.\n\nTogether, Agent AI and LangGraph create a cohesive system where LangGraph orchestrates agent interactions, ensuring that user inputs are analyzed, routed, and processed efficiently. Experimental results demonstrate the potential of this system to enhance multilingual translation accuracy and scalability. By highlighting modular design and automated workflows, this paper sets the stage for further innovations in intelligent machine translation services.\n\n###### Keywords:\n\nLarge Language Model Agent LangChain LangGraph GPT-4o GLM-4 NLP machine translation sequence to sequence PyTorch NMT.\n\n## 1 Introduction\n\nIn machine translation, it has always been one of the hotspots in deep learning research how to choose models that are more efficient and more suitable for translation. In recent years, professional researchers in this field of deep learning and AI have been exploring and improving the relevant models for machine translation, and a lot of experiments have been carried out repeatedly. Artificial intelligence is developing, machine translation technology is also innovating and developing, which makes machine translation move to a more advanced level.\n\nTreisman and Gelade put forward the attention mechanism method [[1](https://arxiv.org/html/2412.03801v1#bib.bib1)], which can simulate the attention model of the human brain, and the probability distribution of attention can be calculated to highlight the influence of one input on the output. In short, when observing a picture, people first notice part of the picture rather than browse the whole content. Then they adjust the focus of attention sequentially in the process of observation. This method of attention mechanism has a good optimization effect on the traditional model. Therefore, in order to improve the system performance in a natural way, the attention mechanism is applied to the sequence-to-sequence network model.\n\nWith the rapid development of large model technology, the field of Machine Translation (MT) has made significant progress. Traditional machine translation methods relied on statistical models and rules, but in recent years, neural network-based models, especially Large Language Models (LLMs) such as GPT-4o, Llama 3.2, ERNIE-4, GLM-4, have become the focus of research due to their powerful capabilities in understanding and generating  ...
#   'response_time': 1.38,
#   'request_id': '23b0e8f8-4f1c-4cfe-ab8b-359a8d590260'}]

# %%
docs[0]
# Out:
# {'query': 'langgraph',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.geeksforgeeks.org/machine-learning/what-is-langgraph/',
#    'title': 'What is LangGraph? - GeeksforGeeks',
#    'content': '# What is LangGraph?\n\nLast Updated : \n10 Oct, 2025\n\nSuggest changes\n\n1 Likes\n\nLangGraph is an open-source framework built by LangChain that streamlines the creation and management of AI agent workflows. At its core, LangGraph combines large language models (LLMs) with graph-based architectures allowing developers to map, organize and optimize how AI agents interact and make decisions.',
#    'score': 0.9345448,
#    'raw_content': '# What is LangGraph?\n\nLast Updated : \n10 Oct, 2025\n\nSuggest changes\n\n1 Likes\n\nLangGraph is an open-source framework built by [LangChain](https://www.geeksforgeeks.org/artificial-intelligence/introduction-to-langchain/) that streamlines the creation and management of AI agent workflows. At its core, LangGraph combines large language models (LLMs) with graph-based architectures allowing developers to map, organize and optimize how AI agents interact and make decisions.\n\nBy treating workflows as interconnected nodes and edges, LangGraph offers a scalable, transparent and developer-friendly way to design advanced AI systems ranging from simple chatbots to multi-agent system.\n\n## Workflow of LangGraph\n\nThe diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.\n\nHere\'s a step-by-step interpretation of the flow:\n\n1. ****Start:**** The process begins with the agent (Assistant) initiating an interaction or task.\n2. ****Assistant:**** This is the central node managing the overall workflow. It controls the movement between tools and sequences based on the current state.\n3. ****Enter Write Sequence:**** If the task requires writing assistance like generating content, the workflow enters a dedicated writing sequence.\n4. ****Write Assistant:**** This specialized module focuses on the writing process. It may loop with tools for refining or editing before completing the sequence.\n5. ****Leave Write Sequence:**** Once the writing task is complete the system exits the write mode.\n6. ****Writer Sensitive Tools & Assistant Tools:**** These nodes provide specialized capabilities. Depending on the state the Assistant routes tasks to tools that enhance writing or perform sensitive operations.\n7. ****End:**** The process concludes once the desired outcome is achieved and all necessary tools have been executed.\n\n## Components of LangGraph\n\nThese core components work together smoothly to help developers build, customize and manage complex AI-driven workflows.\n\n* ****Monitoring mechanism:**** Human-in-the-loop (HITL) ensures humans remain part of the decision-making process. It improves machine learning accuracy by using critical data points instead of relying on random sampling.\n* ****Stateful graphs:**** Each node represents a step in computation and carries forward information from previous steps. This enables continuous, contextual processing of data throughout the workflow.\n* ****Cyclical graphs:**** Graphs that contain loops is used for workflows where certain steps may repeat. It becomes important for complex agent run-times.\n* ****Nodes:**** The individual components or agents within a workflow is called node. They act like “actors” performing tasks or calling tools (e.g., a ToolNode for tool integration).\n* ****Edges:**** Edges determine which node should run next. They can follow fixed paths or branching conditions based on the system state.\n* ****RAG (Retrieval-Augmented Generation):**** [RAG](https://www.geeksforgeeks.org/nlp/what-is-retrieval-augmented-generation-rag/) enhances LLMs by adding relevant external documents as context, improving the accuracy and richness of outputs.\n* ****Workflows:**** Sequences of interactions between nodes. By designing workflows, users combine multiple nodes into powerful, dynamic AI processes.\n* ****APIs:**** A set of tools to programmatically add nodes, modify workflows or extract data. Offers developers flexibility and seamless integration with other systems.\n* ****LangSmith:**** [LangSmith](https://www.geeksforgeeks.org/nlp/introduction-to-langsmith/) is a dedicated API for managing large language models (LLMs). Provides functions for initializing LLMs, creating conditional logic and optimizing performance.\n\n## How LangGraph Scales\n\n* ****Graph-based architecture:**** Ensures AI workflows grow without slowing down or losing efficiency.\n* ****Enhanced decision-making:**** Models relationships b ...
#   {'url': 'https://docs.langchain.com/oss/python/langgraph/overview',
#    'title': 'LangGraph overview - Docs by LangChain',
#    'content': 'Trusted by companies shaping the future of agents— including Klarna, Replit, Elastic, and more— LangGraph is a low-level orchestration framework and runtime for building, managing, and deploying long-running, stateful agents.LangGraph is very low-level, and focused entirely on agent orchestration. Before using LangGraph, we recommend you familiarize yourself with some of the components used to build agents, starting with models and tools.We will commonly use LangChain components throughout the',
#    'score': 0.9314689,
#    'raw_content': 'LangGraph overview - Docs by LangChain\n\n===============\n\n[Skip to main content](https://docs.langchain.com/oss/python/langgraph/overview#content-area)\n\n[Docs by LangChain home page![Image 1: light logo](https://mintcdn.com/langchain-5e9cc07a/Xbr8HuVd9jPi6qTU/images/brand/langchain-docs-teal.svg?fit=max&auto=format&n=Xbr8HuVd9jPi6qTU&q=85&s=16111530672bf976cb54ef2143478342)![Image 2: dark logo](https://mintcdn.com/langchain-5e9cc07a/Xbr8HuVd9jPi6qTU/images/brand/langchain-docs-lilac.svg?fit=max&auto=format&n=Xbr8HuVd9jPi6qTU&q=85&s=b70fb1a2208670492ef94aef14b680be)](https://docs.langchain.com/)LangChain + LangGraph\n\nSearch...\n\nCtrl K\n\n*   [GitHub](https://github.com/langchain-ai)\n*   [Try LangSmith](https://smith.langchain.com/)\n*   [Try LangSmith](https://smith.langchain.com/)\n\nSearch...\n\nNavigation\n\nLangGraph overview\n\n[LangChain](https://docs.langchain.com/oss/python/langchain/overview)[LangGraph](https://docs.langchain.com/oss/python/langgraph/overview)[Deep Agents](https://docs.langchain.com/oss/python/deepagents/overview)[Integrations](https://docs.langchain.com/oss/python/integrations/providers/overview)[Learn](https://docs.langchain.com/oss/python/learn)[Reference](https://docs.langchain.com/oss/python/reference/overview)[Contribute](https://docs.langchain.com/oss/python/contributing/overview)\n\nPython\n\n*   [Overview](https://docs.langchain.com/oss/python/langgraph/overview)\n\n##### LangGraph v1.0\n\n*   [Release notes](https://docs.langchain.com/oss/python/releases/langgraph-v1)\n*   [Migration guide](https://docs.langchain.com/oss/python/migrate/langgraph-v1)\n\n##### Get started\n\n*   [Install](https://docs.langchain.com/oss/python/langgraph/install)\n*   [Quickstart](https://docs.langchain.com/oss/python/langgraph/quickstart)\n*   [Local server](https://docs.langchain.com/oss/python/langgraph/local-server)\n*   [Thinking in LangGraph](https://docs.langchain.com/oss/python/langgraph/thinking-in-langgraph)\n*   [Workflows + agents](https://docs.langchain.com/oss/python/langgraph/workflows-agents)\n\n##### Capabilities\n\n*   [Persistence](https://docs.langchain.com/oss/python/langgraph/persistence)\n*   [Durable execution](https://docs.langchain.com/oss/python/langgraph/durable-execution)\n*   [Streaming](https://docs.langchain.com/oss/python/langgraph/streaming)\n*   [Interrupts](https://docs.langchain.com/oss/python/langgraph/interrupts)\n*   [Time travel](https://docs.langchain.com/oss/python/langgraph/use-time-travel)\n*   [Memory](https://docs.langchain.com/oss/python/langgraph/add-memory)\n*   [Subgraphs](https://docs.langchain.com/oss/python/langgraph/use-subgraphs)\n\n##### Production\n\n*   [Application structure](https://docs.langchain.com/oss/python/langgraph/application-structure)\n*   [Studio](https://docs.langchain.com/oss/python/langgraph/studio)\n*   [Test](https://docs.langchain.com/oss/python/langgraph/test)\n*   [Deploy](https://docs.langchain.com/oss/python/langgraph/deploy)\n*   [Agent Chat UI](https://docs.langchain.com/oss/python/langgraph/ui)\n*   [Observability](https://docs.langchain.com/oss/python/langgraph/observability)\n\n##### LangGraph APIs\n\n*   Graph API \n*   Functional API \n*   [Runtime](https://docs.langchain.com/oss/python/langgraph/pregel)\n\nOn this page\n*   [Install](https://docs.langchain.com/oss/python/langgraph/overview#install)\n*   [Core benefits](https://docs.langchain.com/oss/python/langgraph/overview#core-benefits)\n*   [LangGraph ecosystem](https://docs.langchain.com/oss/python/langgraph/overview#langgraph-ecosystem)\n*   [Acknowledgements](https://docs.langchain.com/oss/python/langgraph/overview#acknowledgements)\n\nLangGraph overview\n==================\n\nCopy page\n\nCopy page\n\n**LangGraph v1.0 is now available!**For a complete list of changes and instructions on how to upgrade your code, see the [release notes](https://docs.langchain.com/oss/python/releases/langgraph-v1) and [migration guide](https://docs.langchai ...
#   {'url': 'https://gunjanvi.medium.com/langgraph-part-1-dd37e2936ca9',
#    'title': 'LangGraph — Part 1 - Gunjan - Medium',
#    'content': 'Sitemap\n\nOpen in app\n\nSign in\n\nWrite\n\nSearch\n\nSign in\n\n# LangGraph — Part 1\n\nGunjan\n\n3 min read\n\n·\n\nSep 2, 2024\n\n--\n\nLangGraph is a library that enables building and managing directed acyclic graphs (DAGs) in the context of natural language processing (NLP). It is designed to help in constructing complex workflows where each node in the graph represents a computational step, often involving language models or other NLP-related tasks.\n\nHow is different from Langchain ?',
#    'score': 0.91795975,
#    'raw_content': '[Sitemap](/sitemap/sitemap.xml)\n\n[Open in app](https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2Fdd37e2936ca9&%7Efeature=LoOpenInAppButton&%7Echannel=ShowPostUnderUser&%7Estage=mobileNavBar&source=post_page---top_nav_layout_nav-----------------------------------------)\n\n[Sign in](https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fgunjanvi.medium.com%2Flanggraph-part-1-dd37e2936ca9&source=post_page---top_nav_layout_nav-----------------------global_nav------------------)\n\n[Write](https://medium.com/m/signin?operation=register&redirect=https%3A%2F%2Fmedium.com%2Fnew-story&source=---top_nav_layout_nav-----------------------new_post_topnav------------------)\n\n[Search](https://medium.com/search?source=post_page---top_nav_layout_nav-----------------------------------------)\n\n[Sign in](https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fgunjanvi.medium.com%2Flanggraph-part-1-dd37e2936ca9&source=post_page---top_nav_layout_nav-----------------------global_nav------------------)\n\n# LangGraph — Part 1\n\n[Gunjan](/?source=post_page---byline--dd37e2936ca9---------------------------------------)\n\n3 min read\n\n·\n\nSep 2, 2024\n\n--\n\nLangGraph is a library that enables building and managing directed acyclic graphs (DAGs) in the context of natural language processing (NLP). It is designed to help in constructing **complex workflows** where each node in the graph represents a computational step, often involving language models or other NLP-related tasks.\n\nHow is different from Langchain ?\n\n* **LangGraph** allows for the creation of both linear and cyclic workflows, offering greater flexibility for complex or iterative processes.\n* **LangChain (with LCEL)** is more suited for linear workflows or state machines, where each step follows a sequential path without revisiting previous steps, making it less suited for workflows that require cycles.\n\n## Core Components\n\n### Nodes\n\nNodes in LangGraph are individual tasks or steps within a workflow, each representing a specific computation or operation that processes data. They are connected by edges, which define dependencies, allowing for the sequential or parallel execution of tasks based on the graph’s structure.\n\n### Edges\n\nEdges in LangGraph represent the dependencies between nodes, defining the order in which tasks should be executed. They ensure that a node only processes data after its prerequisite nodes have completed, allowing for controlled, sequential, or parallel execution within the workflow.\n\n### Conditional Edges\n\nConditional edges in LangGraph are specialized edges that dictate the execution of a node based on the outcome or conditions of its preceding nodes. They enable dynamic workflows, where a node only executes if specific criteria or conditions are met, allowing for more flexible and adaptive processing.\n\n### State Schemas\n\nState Schemas in LangGraph define the possible states a node or process can be in during its execution, along with the transitions between these states based on specific conditions or events. They help manage the flow of a workflow by outlining how and when a node can move from one state to another, ensuring structured and controlled execution within the graph.\n\n### Reducers\n\nReducers in LangGraph are functions that aggregate or combine data from multiple nodes or steps in a workflow. They are used to process and condense the output from various sources into a single result, often playing a crucial role in summarizing or merging data as it moves through the workflow.\n\n### Cyclic Graph\n\nA cyclic graph in LangGraph refers to a graph structure where nodes are connected in such a way that it’s possible to return to the starting node, creating loops or cycles. This allows for iterative processes or repeated execution of certain tasks within the workflow, enabling more complex and dynamic behavior compared to a standard directed acyclic graph (DAG). ...
#   {'url': 'https://www.datacamp.com/tutorial/langgraph-tutorial',
#    'title': 'LangGraph Tutorial: What Is LangGraph and How to Use It?',
#    'content': "Imagine you're building a complex, multi-agent large language model (LLM) application. It's exciting, but it comes with challenges: managing the state of various agents, coordinating their interactions, and handling errors effectively. This is where LangGraph can help.\n\nLangGraph is a library within the LangChain ecosystem designed to tackle these challenges head-on. LangGraph provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured manner. [...] Skip to main content\n\n# LangGraph Tutorial: What Is LangGraph and How to Use It?\n\nLangGraph is a library within the LangChain ecosystem that provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured and efficient manner.\n\nJun 26, 2024  · 12 min read [...] For applications requiring autonomous decision-making, LangGraph enables the creation of agents that can perform tasks independently based on user inputs and predefined logic.\n\nThese agents can execute complex workflows, interact with other systems, and adapt to new information dynamically. LangGraph's structured framework ensures that each agent operates efficiently and effectively, making it suitable for tasks like automated customer support, data processing, and system monitoring.",
#    'score': 0.91399205,
#    'raw_content': '[Skip to main content](#main)\n\n# LangGraph Tutorial: What Is LangGraph and How to Use It?\n\nLangGraph is a library within the LangChain ecosystem that provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured and efficient manner.\n\nJun 26, 2024 \xa0· 12 min read\n\nImagine you\'re building a complex, multi-agent large language model (LLM) application. It\'s exciting, but it comes with challenges: managing the state of various agents, coordinating their interactions, and handling errors effectively. This is where LangGraph can help.\n\nLangGraph is a library within the LangChain ecosystem designed to tackle these challenges head-on. LangGraph provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured manner.\n\nIt simplifies the development process by enabling the creation of cyclical graphs, which are essential for developing agent runtimes. With LangGraph, we can easily build robust, scalable, and flexible multi-agent systems.\n\nIf you want to learn more about the LangChain ecosystem, I recommend this [introduction to LangChain](https://www.datacamp.com/tutorial/introduction-to-langchain-for-data-engineering-and-data-applications). You can also check out our [LangGraph video tutorial](https://www.youtube.com/watch?v=UklCxmEvz2w) below.\n\n## What Is LangGraph?\n\nLangGraph enables us to create stateful, multi-actor applications utilizing LLMs as easily as possible. It extends the capabilities of LangChain, introducing the ability to create and manage cyclical graphs, which are pivotal for developing sophisticated agent runtimes. The core concepts of LangGraph include: graph structure, state management, and coordination.\n\n### Graph structure\n\nImagine your application as a directed graph. In LangGraph, each node represents an LLM agent, and the edges are the communication channels between these agents. This structure allows for clear and manageable workflows, where each agent performs specific tasks and passes information to other agents as needed.\n\n### State management\n\nOne of LangGraph\'s standout features is its automatic state management. This feature enables us to track and persist information across multiple interactions. As agents perform their tasks, the state is dynamically updated, ensuring the system maintains context and responds appropriately to new inputs.\n\n### Coordination\n\nLangGraph ensures agents execute in the correct order and that necessary information is exchanged seamlessly. This coordination is vital for complex applications where multiple agents need to work together to achieve a common goal. By managing the flow of data and the sequence of operations, LangGraph allows developers to focus on the high-level logic of their applications rather than the intricacies of agent coordination.\n\n## Why LangGraph?\n\nAs I mentioned above, LangGraph offers several significant advantages for developers working with complex LLM applications. Here are some of the real-world benefits LangGraph offers.\n\n### Simplified development\n\nLangGraph abstracts away the complexities associated with state management and agent coordination. This means developers can define their workflows and logic without worrying about the underlying mechanisms that ensure data consistency and proper execution order. This simplification accelerates the development process and reduces the likelihood of errors. It’s a game-changer!\n\n### Flexibility\n\nWith LangGraph, developers have the flexibility to define their own agent logic and communication protocols. This allows for highly customized applications tailored to specific use cases. Whether you need a chatbot that can handle various types of user requests or a multi-agent system that performs complex tasks, LangGraph provides the tools to build exactly what you need. It’s all about giving you the power to create.\n\n### Scalability\n\nLangGraph is bui ...
#   {'url': 'https://arxiv.org/html/2412.03801v1',
#    'title': 'Agent AI with LangGraph: A Modular Framework for Enhancing ...',
#    'content': 'As shown in Figure 3, LangGraph is a framework for building agents, allowing developers to create complex workflows by defining states, nodes, and edges. This paper implements a multilingual translation system that can automatically select the appropriate translation agent to translate the text based on the input text that requires translation. The IntentAgent is responsible for parsing the input text and intent, and selecting the suitable translation agent according to the predefined mapping [...] LangChain is an application development framework powered by Large Language Models (LLMs), offering open-source building blocks, components, and third-party integrations that enable developers to construct applications. LangGraph is a framework built upon LangChain, simplifying the creation and management of agents and their runtime environments. In the application of machine translation, LangGraph, through its state management system, allows agents to maintain dialogue and remember contextual [...] machine translation tasks. LangGraph, as a graph-based framework, offers a flexible and efficient way to construct agents that can leverage the capabilities of large language models to perform complex tasks, achieving high-quality machine translation. The research presented in this paper not only provides a new technological path for the field of machine translation but also serves as a reference for other application areas that require complex language understanding and generation',
#    'score': 0.902687,
#    'raw_content': '11institutetext:  Executive Vice President,Ferret Relationship Intelligence   \nBurlingame, CA 94010, USA   \n11email: jialinwangspace@gmail.com   \n<https://www.linkedin.com/in/starspacenlp/> 22institutetext: Intelligent Cloud Network Monitoring Department   \nChina Telecom Shanghai Company,Shanghai, China   \n22email: duanzh.sh@chinatelecom.cn   \n\n# Agent AI with LangGraph: A Modular Framework for Enhancing Machine Translation Using Large Language Models\n\nJialin Wang 11 \u2003\u2003 Zhihua Duan 2 2\n\n###### Abstract\n\nThis paper explores the transformative role of Agent AI and LangGraph in advancing the automation and effectiveness of machine translation (MT). Agents are modular components designed to perform specific tasks, such as translating between particular languages, with specializations like TranslateEnAgent, TranslateFrenchAgent, and TranslateJpAgent for English, French, and Japanese translations, respectively. These agents leverage the powerful semantic capabilities of large language models (LLMs), such as GPT-4o, to ensure accurate, contextually relevant translations while maintaining modularity, scalability, and context retention.\n\nLangGraph, a graph-based framework built on LangChain, simplifies the creation and management of these agents and their workflows. It supports dynamic state management, enabling agents to maintain dialogue context and automates complex workflows by linking agents and facilitating their collaboration. With flexibility, open-source community support, and seamless integration with LLMs, LangGraph empowers agents to deliver high-quality translations.\n\nTogether, Agent AI and LangGraph create a cohesive system where LangGraph orchestrates agent interactions, ensuring that user inputs are analyzed, routed, and processed efficiently. Experimental results demonstrate the potential of this system to enhance multilingual translation accuracy and scalability. By highlighting modular design and automated workflows, this paper sets the stage for further innovations in intelligent machine translation services.\n\n###### Keywords:\n\nLarge Language Model Agent LangChain LangGraph GPT-4o GLM-4 NLP machine translation sequence to sequence PyTorch NMT.\n\n## 1 Introduction\n\nIn machine translation, it has always been one of the hotspots in deep learning research how to choose models that are more efficient and more suitable for translation. In recent years, professional researchers in this field of deep learning and AI have been exploring and improving the relevant models for machine translation, and a lot of experiments have been carried out repeatedly. Artificial intelligence is developing, machine translation technology is also innovating and developing, which makes machine translation move to a more advanced level.\n\nTreisman and Gelade put forward the attention mechanism method [[1](https://arxiv.org/html/2412.03801v1#bib.bib1)], which can simulate the attention model of the human brain, and the probability distribution of attention can be calculated to highlight the influence of one input on the output. In short, when observing a picture, people first notice part of the picture rather than browse the whole content. Then they adjust the focus of attention sequentially in the process of observation. This method of attention mechanism has a good optimization effect on the traditional model. Therefore, in order to improve the system performance in a natural way, the attention mechanism is applied to the sequence-to-sequence network model.\n\nWith the rapid development of large model technology, the field of Machine Translation (MT) has made significant progress. Traditional machine translation methods relied on statistical models and rules, but in recent years, neural network-based models, especially Large Language Models (LLMs) such as GPT-4o, Llama 3.2, ERNIE-4, GLM-4, have become the focus of research due to their powerful capabilities in understanding and generating n ...
#  'response_time': 1.38,
#  'request_id': '23b0e8f8-4f1c-4cfe-ab8b-359a8d590260'}

# %%
output = format_search_query_results(docs, max_tokens=500, include_raw_content=True)

# %%
print(output)
# Out:
# Content from web search:
#
# Source What is LangGraph? - GeeksforGeeks:
# ===
# URL: https://www.geeksforgeeks.org/machine-learning/what-is-langgraph/
# ===
# Most relevant content from source: # What is LangGraph?
#
# Last Updated :
# 10 Oct, 2025
#
# Suggest changes
#
# 1 Likes
#
# LangGraph is an open-source framework built by LangChain that streamlines the creation and management of AI agent workflows. At its core, LangGraph combines large language models (LLMs) with graph-based architectures allowing developers to map, organize and optimize how AI agents interact and make decisions.
# ===
# Raw Content: # What is LangGraph?
#
# Last Updated :
# 10 Oct, 2025
#
# Suggest changes
#
# 1 Likes
#
# LangGraph is an open-source framework built by [LangChain](https://www.geeksforgeeks.org/artificial-intelligence/introduction-to-langchain/) that streamlines the creation and management of AI agent workflows. At its core, LangGraph combines large language models (LLMs) with graph-based architectures allowing developers to map, organize and optimize how AI agents interact and make decisions.
#
# By treating workflows as interconnected nodes and edges, LangGraph offers a scalable, transparent and developer-friendly way to design advanced AI systems ranging from simple chatbots to multi-agent system.
#
# ## Workflow of LangGraph
#
# The diagram below shows how LangGraph structures its agent-based workflow using distinct tools and stages.
#
# Here's a step-by-step interpretation of the flow:
#
# 1. ****Start:**** The process begins with the agent (Assistant) initiating an interaction or task.
# 2. ****Assistant:**** This is the central node managing the overall workflow. It controls the movement between tools and sequences based on the current state.
# 3. ****Enter Write Sequence:**** If the task requires writing assistance like generating content, the workflow enters a dedicated writing sequence.
# 4. ****Write Assistant:**** This specialized module focuses on the writing process. It may loop with tools for refining or editing before completing the sequence.
# 5. ****Leave Write Sequence:**** Once the writing task is complete the system exits the write mode.
# 6. ****Writer Sensitive Tools & Assistant Tools:**** These nodes provide specialized capabilities. Depending on the state the Assistant routes tasks to tools that enhance writing or perform sensitive operations.
# 7. ****End:**** The process concludes once the desired outcome is achieved and all necessary tools have been executed.
#
# ## Components of LangGraph
#
# These core components work together smoothly to help developers build, customize and manage complex AI-driven workflows.
#
# * ****Monitoring mechanism:**** Human-in-the-loop (HITL) ensures humans remain part of the decision-making process. It improves machine learning accuracy by using critical data points instead of relying on random sampling.
# * ****Stateful graphs:**** Each node represents a step in computation and carries forward information from previous steps. This enables continuous, contextual processing of data throughout the workflow.
# * ****Cyclical graphs:**** Graphs that contain loops is used for workflows where certain steps may repeat. It becomes important for complex agent run-times.
# * ****Nodes:**** The individual components or
#
# Source LangGraph overview - Docs by LangChain:
# ===
# URL: https://docs.langchain.com/oss/python/langgraph/overview
# ===
# Most relevant content from source: Trusted by companies shaping the future of agents— including Klarna, Replit, Elastic, and more— LangGraph is a low-level orchestration framework and runtime for building, managing, and deploying long-running, stateful agents.LangGraph is very low-level, and focused entirely on agent orchestration. Before using LangGraph, we recommend you familiarize yourself with some of the components used to build agents, starting with models and tools.We will commonly use LangChain components throughout the
# ===
# Raw Content: LangGraph overview - Docs by LangChain
#
# ===============
#
# [Skip to main content](https://docs.langchain.com/oss/python/langgraph/overview#content-area)
#
# [Docs by LangChain home page![Image 1: light logo](https://mintcdn.com/langchain-5e9cc07a/Xbr8HuVd9jPi6qTU/images/brand/langchain-docs-teal.svg?fit=max&auto=format&n=Xbr8HuVd9jPi6qTU&q=85&s=16111530672bf976cb54ef2143478342)![Image 2: dark logo](https://mintcdn.com/langchain-5e9cc07a/Xbr8HuVd9jPi6qTU/images/brand/langchain-docs-lilac.svg?fit=max&auto=format&n=Xbr8HuVd9jPi6qTU&q=85&s=b70fb1a2208670492ef94aef14b680be)](https://docs.langchain.com/)LangChain + LangGraph
#
# Search...
#
# Ctrl K
#
# *   [GitHub](https://github.com/langchain-ai)
# *   [Try LangSmith](https://smith.langchain.com/)
# *   [Try LangSmith](https://smith.langchain.com/)
#
# Search...
#
# Navigation
#
# LangGraph overview
#
# [LangChain](https://docs.langchain.com/oss/python/langchain/overview)[LangGraph](https://docs.langchain.com/oss/python/langgraph/overview)[Deep Agents](https://docs.langchain.com/oss/python/deepagents/overview)[Integrations](https://docs.langchain.com/oss/python/integrations/providers/overview)[Learn](https://docs.langchain.com/oss/python/learn)[Reference](https://docs.langchain.com/oss/python/reference/overview)[Contribute](https://docs.langchain.com/oss/python/contributing/overview)
#
# Python
#
# *   [Overview](https://docs.langchain.com/oss/python/langgraph/overview)
#
# ##### LangGraph v1.0
#
# *   [Release notes](https://docs.langchain.com/oss/python/releases/langgraph-v1)
# *   [Migration guide](https://docs.langchain.com/oss/python/migrate/langgraph-v1)
#
# ##### Get started
#
# *   [Install](https://docs.langchain.com/oss/python/langgraph/install)
# *   [Quickstart
#
# Source LangGraph — Part 1 - Gunjan - Medium:
# ===
# URL: https://gunjanvi.medium.com/langgraph-part-1-dd37e2936ca9
# ===
# Most relevant content from source: Sitemap
#
# Open in app
#
# Sign in
#
# Write
#
# Search
#
# Sign in
#
# # LangGraph — Part 1
#
# Gunjan
#
# 3 min read
#
# ·
#
# Sep 2, 2024
#
# --
#
# LangGraph is a library that enables building and managing directed acyclic graphs (DAGs) in the context of natural language processing (NLP). It is designed to help in constructing complex workflows where each node in the graph represents a computational step, often involving language models or other NLP-related tasks.
#
# How is different from Langchain ?
# ===
# Raw Content: [Sitemap](/sitemap/sitemap.xml)
#
# [Open in app](https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2Fdd37e2936ca9&%7Efeature=LoOpenInAppButton&%7Echannel=ShowPostUnderUser&%7Estage=mobileNavBar&source=post_page---top_nav_layout_nav-----------------------------------------)
#
# [Sign in](https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fgunjanvi.medium.com%2Flanggraph-part-1-dd37e2936ca9&source=post_page---top_nav_layout_nav-----------------------global_nav------------------)
#
# [Write](https://medium.com/m/signin?operation=register&redirect=https%3A%2F%2Fmedium.com%2Fnew-story&source=---top_nav_layout_nav-----------------------new_post_topnav------------------)
#
# [Search](https://medium.com/search?source=post_page---top_nav_layout_nav-----------------------------------------)
#
# [Sign in](https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fgunjanvi.medium.com%2Flanggraph-part-1-dd37e2936ca9&source=post_page---top_nav_layout_nav-----------------------global_nav------------------)
#
# # LangGraph — Part 1
#
# [Gunjan](/?source=post_page---byline--dd37e2936ca9---------------------------------------)
#
# 3 min read
#
# ·
#
# Sep 2, 2024
#
# --
#
# LangGraph is a library that enables building and managing directed acyclic graphs (DAGs) in the context of natural language processing (NLP). It is designed to help in constructing **complex workflows** where each node in the graph represents a computational step, often involving language models or other NLP-related tasks.
#
# How is different from Langchain ?
#
# * **LangGraph** allows for the creation of both linear and cyclic workflows, offering greater flexibility for complex or iterative processes.
# * **LangChain (with LCEL)** is more suited for linear workflows or state machines, where each step follows a sequential path without revisiting previous steps, making it less suited for workflows that require cycles.
#
# ## Core Components
#
# ### Nodes
#
# Nodes in LangGraph are individual tasks or steps within a workflow, each representing a specific computation or operation that processes data
#
# Source LangGraph Tutorial: What Is LangGraph and How to Use It?:
# ===
# URL: https://www.datacamp.com/tutorial/langgraph-tutorial
# ===
# Most relevant content from source: Imagine you're building a complex, multi-agent large language model (LLM) application. It's exciting, but it comes with challenges: managing the state of various agents, coordinating their interactions, and handling errors effectively. This is where LangGraph can help.
#
# LangGraph is a library within the LangChain ecosystem designed to tackle these challenges head-on. LangGraph provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured manner. [...] Skip to main content
#
# # LangGraph Tutorial: What Is LangGraph and How to Use It?
#
# LangGraph is a library within the LangChain ecosystem that provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured and efficient manner.
#
# Jun 26, 2024  · 12 min read [...] For applications requiring autonomous decision-making, LangGraph enables the creation of agents that can perform tasks independently based on user inputs and predefined logic.
#
# These agents can execute complex workflows, interact with other systems, and adapt to new information dynamically. LangGraph's structured framework ensures that each agent operates efficiently and effectively, making it suitable for tasks like automated customer support, data processing, and system monitoring.
# ===
# Raw Content: [Skip to main content](#main)
#
# # LangGraph Tutorial: What Is LangGraph and How to Use It?
#
# LangGraph is a library within the LangChain ecosystem that provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured and efficient manner.
#
# Jun 26, 2024  · 12 min read
#
# Imagine you're building a complex, multi-agent large language model (LLM) application. It's exciting, but it comes with challenges: managing the state of various agents, coordinating their interactions, and handling errors effectively. This is where LangGraph can help.
#
# LangGraph is a library within the LangChain ecosystem designed to tackle these challenges head-on. LangGraph provides a framework for defining, coordinating, and executing multiple LLM agents (or chains) in a structured manner.
#
# It simplifies the development process by enabling the creation of cyclical graphs, which are essential for developing agent runtimes. With LangGraph, we can easily build robust, scalable, and flexible multi-agent systems.
#
# If you want to learn more about the LangChain ecosystem, I recommend this [introduction to LangChain](https://www.datacamp.com/tutorial/introduction-to-langchain-for-data-engineering-and-data-applications). You can also check out our [LangGraph video tutorial](https://www.youtube.com/watch?v=UklCxmEvz2w) below.
#
# ## What Is LangGraph?
#
# LangGraph enables us to create stateful, multi-actor applications utilizing LLMs as easily as possible. It extends the capabilities of LangChain, introducing the ability to create and manage cyclical graphs, which are pivotal for developing sophisticated agent runtimes. The core concepts of LangGraph include: graph structure, state management, and coordination.
#
# ### Graph structure
#
# Imagine your application as a directed graph. In LangGraph, each node represents an LLM agent, and the edges are the communication channels between these agents. This structure allows for clear and manageable workflows, where each agent performs specific tasks and passes information to other agents as needed.
#
# ### State management
#
# One of LangGraph's standout features is its automatic state management. This feature enables us to track and persist information across multiple interactions. As agents perform their tasks, the state is dynamically updated, ensuring the system maintains context and responds appropriately to new inputs.
#
# ### Coordination
#
# LangGraph ensures agents execute in the correct order and that necessary information is exchanged seamlessly. This coordination is vital for complex
#
# Source Agent AI with LangGraph: A Modular Framework for Enhancing ...:
# ===
# URL: https://arxiv.org/html/2412.03801v1
# ===
# Most relevant content from source: As shown in Figure 3, LangGraph is a framework for building agents, allowing developers to create complex workflows by defining states, nodes, and edges. This paper implements a multilingual translation system that can automatically select the appropriate translation agent to translate the text based on the input text that requires translation. The IntentAgent is responsible for parsing the input text and intent, and selecting the suitable translation agent according to the predefined mapping [...] LangChain is an application development framework powered by Large Language Models (LLMs), offering open-source building blocks, components, and third-party integrations that enable developers to construct applications. LangGraph is a framework built upon LangChain, simplifying the creation and management of agents and their runtime environments. In the application of machine translation, LangGraph, through its state management system, allows agents to maintain dialogue and remember contextual [...] machine translation tasks. LangGraph, as a graph-based framework, offers a flexible and efficient way to construct agents that can leverage the capabilities of large language models to perform complex tasks, achieving high-quality machine translation. The research presented in this paper not only provides a new technological path for the field of machine translation but also serves as a reference for other application areas that require complex language understanding and generation
# ===
# Raw Content: 11institutetext:  Executive Vice President,Ferret Relationship Intelligence
# Burlingame, CA 94010, USA
# 11email: jialinwangspace@gmail.com
# <https://www.linkedin.com/in/starspacenlp/> 22institutetext: Intelligent Cloud Network Monitoring Department
# China Telecom Shanghai Company,Shanghai, China
# 22email: duanzh.sh@chinatelecom.cn
#
# # Agent AI with LangGraph: A Modular Framework for Enhancing Machine Translation Using Large Language Models
#
# Jialin Wang 11    Zhihua Duan 2 2
#
# ###### Abstract
#
# This paper explores the transformative role of Agent AI and LangGraph in advancing the automation and effectiveness of machine translation (MT). Agents are modular components designed to perform specific tasks, such as translating between particular languages, with specializations like TranslateEnAgent, TranslateFrenchAgent, and TranslateJpAgent for English, French, and Japanese translations, respectively. These agents leverage the powerful semantic capabilities of large language models (LLMs), such as GPT-4o, to ensure accurate, contextually relevant translations while maintaining modularity, scalability, and context retention.
#
# LangGraph, a graph-based framework built on LangChain, simplifies the creation and management of these agents and their workflows. It supports dynamic state management, enabling agents to maintain dialogue context and automates complex workflows by linking agents and facilitating their collaboration. With flexibility, open-source community support, and seamless integration with LLMs, LangGraph empowers agents to deliver high-quality translations.
#
# Together, Agent AI and LangGraph create a cohesive system where LangGraph orchestrates agent interactions, ensuring that user inputs are analyzed, routed, and processed efficiently. Experimental results demonstrate the potential of this system to enhance multilingual translation accuracy and scalability. By highlighting modular design and automated workflows, this paper sets the stage for further innovations in intelligent machine translation services.
#
# ###### Keywords:
#
# Large Language Model Agent LangChain LangGraph GPT-4o GLM-4 NLP machine translation sequence to sequence PyTorch NMT.
#
# ## 1 Introduction
#
# In machine translation, it has always been one of the hotspots in deep learning research how to choose models that are more efficient and more suitable for translation. In recent years, professional researchers in this field of deep learning and AI have been exploring and improving the relevant models for machine translation, and a lot of experiments have been carried out repeatedly. Artificial

# %% [markdown]
# ## Default Report Template
#
# This is the starting point for the LLM to get an idea of how to build a general report and it will use this to build a custom report structure

# %%
# Structure
DEFAULT_REPORT_STRUCTURE = """The report structure should focus on breaking-down the user-provided topic
                              and building a comprehensive report in markdown using the following format:

                              1. Introduction (no web search needed)
                                    - Brief overview of the topic area

                              2. Main Body Sections:
                                    - Each section should focus on a sub-topic of the user-provided topic
                                    - Include any key concepts and definitions
                                    - Provide real-world examples or case studies where applicable

                              3. Conclusion (no web search needed)
                                    - Aim for 1 structural element (either a list of table) that distills the main body sections
                                    - Provide a concise summary of the report

                              When generating the final response in markdown, if there are special characters in the text,
                              such as the dollar symbol, ensure they are escaped properly for correct rendering e.g $25.5 should become \$25.5
                          """
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\$'
# <>:18: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/b2/_3vm0kv95fx3hvhfst25c46r0000gp/T/ipykernel_43336/1837009091.py:18: SyntaxWarning: invalid escape sequence '\$'
#   such as the dollar symbol, ensure they are escaped properly for correct rendering e.g $25.5 should become \$25.5

# %% [markdown]
# ## Instruction Prompts for Report Planner
#
# There are two main instruction prompts:
#
# - __REPORT_PLAN_QUERY_GENERATOR_PROMPT:__ Helps the LLM to generate an initial list of questions based on the topic to get more information from the web about that topic so that it can plan the overall sections and structure of the report
#
# - __REPORT_PLAN_SECTION_GENERATOR_PROMPT:__ Here we feed the LLM with the default report template, the topic name and the search results from the intial queries generated to create a detailed structure for the report. The LLM will generate a structured response of the following fields for each major section which will be in the report (this is just the report structure - no content is created at this step):
#     - Name - Name for this section of the report.
#     - Description - Brief overview of the main topics and concepts to be covered in this section.
#     - Research - Whether to perform web search for this section of the report or not.
#     - Content - The content of the section, which you will leave blank for now.

# %%
REPORT_PLAN_QUERY_GENERATOR_PROMPT = """You are an expert technical report writer, helping to plan a report.

The report will be focused on the following topic:
{topic}

The report structure will follow these guidelines:
{report_organization}

Your goal is to generate {number_of_queries} search queries that will help gather comprehensive information for planning the report sections.

The query should:
1. Be related to the topic
2. Help satisfy the requirements specified in the report organization

Make the query specific enough to find high-quality, relevant sources while covering the depth and breadth needed for the report structure.
"""

# %%
REPORT_PLAN_SECTION_GENERATOR_PROMPT = """You are an expert technical report writer, helping to plan a report.

Your goal is to generate the outline of the sections of the report.

The overall topic of the report is:
{topic}

The report should follow this organizational structure:
{report_organization}

You should reflect on this additional context information from web searches to plan the main sections of the report:
{search_context}

Now, generate the sections of the report. Each section should have the following fields:
- Name - Name for this section of the report.
- Description - Brief overview of the main topics and concepts to be covered in this section.
- Research - Whether to perform web search for this section of the report or not.
- Content - The content of the section, which you will leave blank for now.

Consider which sections require web search.
For example, introduction and conclusion will not require research because they will distill information from other parts of the report.
"""

# %% [markdown]
# ## Node Function for Report Planner
#
# ![](https://i.imgur.com/54Jyv71.png)
#
# This function uses the two prompts created above to:
#  - First generate some queries based on the user topic
#  - Search the web and get some information on these queries
#  - Use this information to generate the overall structure of the report with the key sections necessary to be created

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

llm = ChatOpenAI(model_name="gpt-4o", temperature=0)

async def generate_report_plan(state: ReportState):
    """Generate the overall plan for building the report"""
    topic = state["topic"]
    print('--- Generating Report Plan ---')

    report_structure = DEFAULT_REPORT_STRUCTURE
    number_of_queries = 8

    structured_llm = llm.with_structured_output(Queries)

    system_instructions_query = REPORT_PLAN_QUERY_GENERATOR_PROMPT.format(
        topic=topic,
        report_organization=report_structure,
        number_of_queries=number_of_queries
    )

    try:
        # Generate queries
        results = structured_llm.invoke([
            SystemMessage(content=system_instructions_query),
            HumanMessage(content='Generate search queries that will help with planning the sections of the report.')
        ])

        # Convert SearchQuery objects to strings
        query_list = [
            query.search_query if isinstance(query, SearchQuery) else str(query)
            for query in results.queries
        ]

        # Search web and ensure we wait for results
        search_docs = await run_search_queries(
            query_list,
            num_results=5,
            include_raw_content=False
        )

        if not search_docs:
            print("Warning: No search results returned")
            search_context = "No search results available."
        else:
            search_context = format_search_query_results(
                search_docs,
                include_raw_content=False
            )

        # Generate sections
        system_instructions_sections = REPORT_PLAN_SECTION_GENERATOR_PROMPT.format(
            topic=topic,
            report_organization=report_structure,
            search_context=search_context
        )

        structured_llm = llm.with_structured_output(Sections)
        report_sections = structured_llm.invoke([
            SystemMessage(content=system_instructions_sections),
            HumanMessage(content="Generate the sections of the report. Your response must include a 'sections' field containing a list of sections. Each section must have: name, description, plan, research, and content fields.")
        ])

        print('--- Generating Report Plan Completed ---')
        return {"sections": report_sections.sections}

    except Exception as e:
        print(f"Error in generate_report_plan: {e}")
        return {"sections": []}

# %% [markdown]
# ## Instruction Prompts for Section Builder - Query Generator
#
# There is one main instruction prompt:
#
# - __REPORT_SECTION_QUERY_GENERATOR_PROMPT:__ Helps the LLM to generate a comprehensive list of questions for the topic of that specific section which needs to be built

# %%
REPORT_SECTION_QUERY_GENERATOR_PROMPT = """Your goal is to generate targeted web search queries that will gather comprehensive information for writing a technical report section.

Topic for this section:
{section_topic}

When generating {number_of_queries} search queries, ensure that they:
1. Cover different aspects of the topic (e.g., core features, real-world applications, technical architecture)
2. Include specific technical terms related to the topic
3. Target recent information by including year markers where relevant (e.g., "2024")
4. Look for comparisons or differentiators from similar technologies/approaches
5. Search for both official documentation and practical implementation examples

Your queries should be:
- Specific enough to avoid generic results
- Technical enough to capture detailed implementation information
- Diverse enough to cover all aspects of the section plan
- Focused on authoritative sources (documentation, technical blogs, academic papers)"""

# %% [markdown]
# ## Node Function for Section Builder - Generate Queries (Query Generator)
#
# This uses the section topic and the instruction prompt above to generate some questions for researching on the web for getting useful information on the section topic

# %%
def generate_queries(state: SectionState):
    """ Generate search queries for a specific report section """



    # Get state
    section = state["section"]
    print('--- Generating Search Queries for Section: '+ section.name +' ---')

    # Get configuration
    number_of_queries = 5

    # Generate queries
    structured_llm = llm.with_structured_output(Queries)

    # Format system instructions
    system_instructions = REPORT_SECTION_QUERY_GENERATOR_PROMPT.format(section_topic=section.description,
                                                                       number_of_queries=number_of_queries)

    # Generate queries
    user_instruction = "Generate search queries on the provided topic."
    search_queries = structured_llm.invoke([SystemMessage(content=system_instructions),
                                     HumanMessage(content=user_instruction)])

    print('--- Generating Search Queries for Section: '+ section.name +' Completed ---')

    return {"search_queries": search_queries.queries}

# %% [markdown]
# ## Node Function for Section Builder - Search Web
#
# Takes the queries generated by `generate_queries(...)`for a specific section, searches the web and formats the search results using the utility functions we defined earlier

# %%
async def search_web(state: SectionState):
    """ Search the web for each query, then return a list of raw sources and a formatted string of sources."""

    # Get state
    search_queries = state["search_queries"]

    print('--- Searching Web for Queries ---')

    # Web search
    query_list = [query.search_query for query in search_queries]
    search_docs = await run_search_queries(search_queries, num_results=6, include_raw_content=True)

    # Deduplicate and format sources
    search_context = format_search_query_results(search_docs, max_tokens=4000, include_raw_content=True)

    print('--- Searching Web for Queries Completed ---')

    return {"source_str": search_context}

# %% [markdown]
# ## Instruction Prompts for Section Builder - Section Writer
#
# There is one main instruction prompt:
#
# - __SECTION_WRITER_PROMPT:__ Constrains the LLM to generate and write the content for a specific section using certain guidelines on style, structure, length, approach and the documents obtained from the web earlier using the `search_web(...)` function are also sent.

# %%
SECTION_WRITER_PROMPT = """You are an expert technical writer crafting one specific section of a technical report.

Title for the section:
{section_title}

Topic for this section:
{section_topic}

Guidelines for writing:

1. Technical Accuracy:
- Include specific version numbers
- Reference concrete metrics/benchmarks
- Cite official documentation
- Use technical terminology precisely

2. Length and Style:
- Strict 150-200 word limit
- No marketing language
- Technical focus
- Write in simple, clear language do not use complex words unnecessarily
- Start with your most important insight in **bold**
- Use short paragraphs (2-3 sentences max)

3. Structure:
- Use ## for section title (Markdown format)
- Only use ONE structural element IF it helps clarify your point:
  * Either a focused table comparing 2-3 key items (using Markdown table syntax)
  * Or a short list (3-5 items) using proper Markdown list syntax:
    - Use `*` or `-` for unordered lists
    - Use `1.` for ordered lists
    - Ensure proper indentation and spacing
- End with ### Sources that references the below source material formatted as:
  * List each source with title, date, and URL
  * Format: `- Title : URL`

3. Writing Approach:
- Include at least one specific example or case study if available
- Use concrete details over general statements
- Make every word count
- No preamble prior to creating the section content
- Focus on your single most important point

4. Use this source material obtained from web searches to help write the section:
{context}

5. Quality Checks:
- Format should be Markdown
- Exactly 150-200 words (excluding title and sources)
- Careful use of only ONE structural element (table or bullet list) and only if it helps clarify your point
- One specific example / case study if available
- Starts with bold insight
- No preamble prior to creating the section content
- Sources cited at end
- If there are special characters in the text, such as the dollar symbol,
  ensure they are escaped properly for correct rendering e.g $25.5 should become \$25.5
"""
# Out:
# <>:56: SyntaxWarning: invalid escape sequence '\$'
# <>:56: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/b2/_3vm0kv95fx3hvhfst25c46r0000gp/T/ipykernel_43336/4210525775.py:56: SyntaxWarning: invalid escape sequence '\$'
#   ensure they are escaped properly for correct rendering e.g $25.5 should become \$25.5

# %% [markdown]
# ## Node Function for Section Builder - Write Section (Section Writer)
#
# Uses the SECTION_WRITER_PROMPT from above and feeds it with the section name, description and web search documents and passes it to an LLM to write the content for that section

# %%
def write_section(state: SectionState):
    """ Write a section of the report """

    # Get state
    section = state["section"]
    source_str = state["source_str"]

    print('--- Writing Section : '+ section.name +' ---')

    # Format system instructions
    system_instructions = SECTION_WRITER_PROMPT.format(section_title=section.name,
                                                       section_topic=section.description,
                                                       context=source_str)

    # Generate section
    user_instruction = "Generate a report section based on the provided sources."
    section_content = llm.invoke([SystemMessage(content=system_instructions),
                                  HumanMessage(content=user_instruction)])

    # Write content to the section object
    section.content = section_content.content

    print('--- Writing Section : '+ section.name +' Completed ---')

    # Write the updated section to completed sections
    return {"completed_sections": [section]}

# %% [markdown]
# ## Create the Section Builder Sub-Agent
#
# ![](https://i.imgur.com/5VEYGrQ.png)
#
# This agent (or to be more specific, sub-agent) will be called several times in parallel, once for each section to search the web, get content and then write up that specific section

# %%
from langgraph.graph import StateGraph, START, END

# Add nodes and edges
section_builder = StateGraph(SectionState, output=SectionOutputState)
section_builder.add_node("generate_queries", generate_queries)
section_builder.add_node("search_web", search_web)
section_builder.add_node("write_section", write_section)

section_builder.add_edge(START, "generate_queries")
section_builder.add_edge("generate_queries", "search_web")
section_builder.add_edge("search_web", "write_section")
section_builder.add_edge("write_section", END)
section_builder_subagent = section_builder.compile()

# %%
# Display the graph
from IPython.display import display, Image
Image(section_builder_subagent.get_graph().draw_mermaid_png())

# %% [markdown]
# ### Create Dynamic Parallelization Node Function - Parallelize Section Writing
#
# `Send(...)` is used to parallelize and call the `section_builder_subagent` once for each section to write up the content (in parallel)

# %%
from langgraph.constants import Send

def parallelize_section_writing(state: ReportState):
    """ This is the "map" step when we kick off web research for some sections of the report in parallel and then write the section"""

    # Kick off section writing in parallel via Send() API for any sections that require research
    return [
        Send("section_builder_with_web_search", # name of the subagent node
             {"section": s})
            for s in state["sections"]
              if s.research
    ]

# %% [markdown]
# ## Create Format Sections Node Function
#
# This is basically the section where all the sections are formatted and combined together into one big document.
#
# ![](https://i.imgur.com/6e5ZWK4.png)

# %%
def format_sections(sections: list[Section]) -> str:
    """ Format a list of report sections into a single text string """
    formatted_str = ""
    for idx, section in enumerate(sections, 1):
        formatted_str += f"""
{'='*60}
Section {idx}: {section.name}
{'='*60}
Description:
{section.description}
Requires Research:
{section.research}

Content:
{section.content if section.content else '[Not yet written]'}

"""
    return formatted_str


def format_completed_sections(state: ReportState):
    """ Gather completed sections from research and format them as context for writing the final sections """

    print('--- Formatting Completed Sections ---')

    # List of completed sections
    completed_sections = state["completed_sections"]

    # Format completed section to str to use as context for final sections
    completed_report_sections = format_sections(completed_sections)

    print('--- Formatting Completed Sections is Done ---')

    return {"report_sections_from_research": completed_report_sections}

# %% [markdown]
# ## Instruction Prompts for Final Section
#
# There is one main instruction prompt:
#
# - __FINAL_SECTION_WRITER_PROMPT:__ Constrains the LLM to generate and write the content for either the introduction OR conclusion using certain guidelines on style, structure, length, approach and the content of the already written sections are also sent.

# %%
FINAL_SECTION_WRITER_PROMPT = """You are an expert technical writer crafting a section that synthesizes information from the rest of the report.

Title for the section:
{section_title}

Topic for this section:
{section_topic}

Available report content of already completed sections:
{context}

1. Section-Specific Approach:

For Introduction:
- Use # for report title (Markdown format)
- 50-100 word limit
- Write in simple and clear language
- Focus on the core motivation for the report in 1-2 paragraphs
- Use a clear narrative arc to introduce the report
- Include NO structural elements (no lists or tables)
- No sources section needed

For Conclusion/Summary:
- Use ## for section title (Markdown format)
- 100-150 word limit
- For comparative reports:
    * Must include a focused comparison table using Markdown table syntax
    * Table should distill insights from the report
    * Keep table entries clear and concise
- For non-comparative reports:
    * Only use ONE structural element IF it helps distill the points made in the report:
    * Either a focused table comparing items present in the report (using Markdown table syntax)
    * Or a short list using proper Markdown list syntax:
      - Use `*` or `-` for unordered lists
      - Use `1.` for ordered lists
      - Ensure proper indentation and spacing
- End with specific next steps or implications
- No sources section needed

3. Writing Approach:
- Use concrete details over general statements
- Make every word count
- Focus on your single most important point

4. Quality Checks:
- For introduction: 50-100 word limit, # for report title, no structural elements, no sources section
- For conclusion: 100-150 word limit, ## for section title, only ONE structural element at most, no sources section
- Markdown format
- Do not include word count or any preamble in your response
- If there are special characters in the text, such as the dollar symbol,
  ensure they are escaped properly for correct rendering e.g $25.5 should become \$25.5"""
# Out:
# <>:51: SyntaxWarning: invalid escape sequence '\$'
# <>:51: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/b2/_3vm0kv95fx3hvhfst25c46r0000gp/T/ipykernel_43336/1591155706.py:51: SyntaxWarning: invalid escape sequence '\$'
#   ensure they are escaped properly for correct rendering e.g $25.5 should become \$25.5"""

# %% [markdown]
# ## Create Write Final Sections Node Function
#
# This function uses the instruction prompot FINAL_SECTION_WRITER_PROMPT mentioned above to write up the introduction and conclusion. This function will be executed in parallel using `Send(...)` below
#
# ![](https://i.imgur.com/pRv4PX8.png)

# %%
def write_final_sections(state: SectionState):
    """ Write the final sections of the report, which do not require web search and use the completed sections as context"""

    # Get state
    section = state["section"]
    completed_report_sections = state["report_sections_from_research"]

    print('--- Writing Final Section: '+ section.name + ' ---')

    # Format system instructions
    system_instructions = FINAL_SECTION_WRITER_PROMPT.format(section_title=section.name,
                                                             section_topic=section.description,
                                                             context=completed_report_sections)

    # Generate section
    user_instruction = "Craft a report section based on the provided sources."
    section_content = llm.invoke([SystemMessage(content=system_instructions),
                                  HumanMessage(content=user_instruction)])

    # Write content to section
    section.content = section_content.content

    print('--- Writing Final Section: '+ section.name + ' Completed ---')

    # Write the updated section to completed sections
    return {"completed_sections": [section]}

# %% [markdown]
# ### Create Dynamic Parallelization Node Function - Parallelize Final Section Writing
#
# `Send(...)` is used to parallelize and call the `write_final_sections` once for each of the introduction and conclusion to write up the content (in parallel)

# %%
from langgraph.constants import Send

def parallelize_final_section_writing(state: ReportState):
    """ Write any final sections using the Send API to parallelize the process """

    # Kick off section writing in parallel via Send() API for any sections that do not require research
    return [
        Send("write_final_sections",
             {"section": s, "report_sections_from_research": state["report_sections_from_research"]})
                 for s in state["sections"]
                    if not s.research
    ]

# %% [markdown]
# ## Compile Final Report Node Function
#
# This function combines all the sections of the report together and compiles it into the final report document
#
# ![](https://i.imgur.com/wLxCNZ5.png)

# %%
def compile_final_report(state: ReportState):
    """ Compile the final report """

    # Get sections
    sections = state["sections"]
    completed_sections = {s.name: s.content for s in state["completed_sections"]}

    print('--- Compiling Final Report ---')

    # Update sections with completed content while maintaining original order
    for section in sections:
        section.content = completed_sections[section.name]

    # Compile final report
    all_sections = "\n\n".join([s.content for s in sections])
    # Escape unescaped $ symbols to display properly in Markdown
    formatted_sections = all_sections.replace("\\$", "TEMP_PLACEHOLDER")  # Temporarily mark already escaped $
    formatted_sections = formatted_sections.replace("$", "\\$")  # Escape all $
    formatted_sections = formatted_sections.replace("TEMP_PLACEHOLDER", "\\$")  # Restore originally escaped $

# Now escaped_sections contains the properly escaped Markdown text


    print('--- Compiling Final Report Done ---')

    return {"final_report": formatted_sections}

# %% [markdown]
# ## Build our Report Writer Planning Agent
#
# We now bring all the defined components and sub-agent together and build our planning agent
#
# ![](https://i.imgur.com/STSC73k.png)

# %%
builder = StateGraph(ReportState, input=ReportStateInput, output=ReportStateOutput)

builder.add_node("generate_report_plan", generate_report_plan)
builder.add_node("section_builder_with_web_search", section_builder_subagent)
builder.add_node("format_completed_sections", format_completed_sections)
builder.add_node("write_final_sections", write_final_sections)
builder.add_node("compile_final_report", compile_final_report)

builder.add_edge(START, "generate_report_plan")
builder.add_conditional_edges("generate_report_plan",
                              parallelize_section_writing,
                              ["section_builder_with_web_search"])
builder.add_edge("section_builder_with_web_search", "format_completed_sections")
builder.add_conditional_edges("format_completed_sections",
                              parallelize_final_section_writing,
                              ["write_final_sections"])
builder.add_edge("write_final_sections", "compile_final_report")
builder.add_edge("compile_final_report", END)

reporter_agent = builder.compile()

# %%
display(Image(reporter_agent.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# ## Run and Test our Agent

# %%
from IPython.display import display
from rich.console import Console
from rich.markdown import Markdown as RichMarkdown

async def call_planner_agent(agent, prompt, config={"recursion_limit": 50}, verbose=False):
    events = agent.astream(
        {'topic' : prompt},
        config,
        stream_mode="values",
    )

    async for event in events:
        for k, v in event.items():
            if verbose:
                if k != "__end__":
                    display(RichMarkdown(repr(k) + ' -> ' + repr(v)))
            if k == 'final_report':
                print('='*50)
                print('Final Report:')
                md = RichMarkdown(v)
                display(md)

# %%
topic = "Detailed report on how to build Agentic AI systems, design patterns and current frameworks"
await call_planner_agent(agent=reporter_agent,
                         prompt=topic)
# Out:
# --- Generating Report Plan ---
# --- Generating Report Plan Completed ---
# --- Generating Search Queries for Section: Challenges and Considerations in Agentic AI Development ---
# --- Generating Search Queries for Section: Understanding Agentic AI ---
# --- Generating Search Queries for Section: Frameworks for Building Agentic AI Systems ---
# --- Generating Search Queries for Section: Real-World Applications of Agentic AI ---
# --- Generating Search Queries for Section: Design Patterns in Agentic AI ---
# --- Generating Search Queries for Section: Frameworks for Building Agentic AI Systems Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Challenges and Considerations in Agentic AI Development Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Design Patterns in Agentic AI Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Real-World Applications of Agentic AI Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Understanding Agentic AI Completed ---
# --- Searching Web for Queries ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Challenges and Considerations in Agentic AI Development ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Real-World Applications of Agentic AI ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Understanding Agentic AI ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Design Patterns in Agentic AI ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Frameworks for Building Agentic AI Systems ---
# --- Writing Section : Understanding Agentic AI Completed ---
# --- Writing Section : Real-World Applications of Agentic AI Completed ---
# --- Writing Section : Design Patterns in Agentic AI Completed ---
# --- Writing Section : Frameworks for Building Agentic AI Systems Completed ---
# --- Writing Section : Challenges and Considerations in Agentic AI Development Completed ---
# --- Formatting Completed Sections ---
# --- Formatting Completed Sections is Done ---
# --- Writing Final Section: Conclusion ---
# --- Writing Final Section: Introduction ---
# --- Writing Final Section: Introduction Completed ---
# --- Writing Final Section: Conclusion Completed ---
# --- Compiling Final Report ---
# --- Compiling Final Report Done ---
# ==================================================
# Final Report:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                  Introduction                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# Agentic AI systems represent a transformative leap in artificial intelligence, characterized by their autonomy,
# adaptability, and goal-oriented behavior. Unlike traditional AI, which operates within predefined constraints,
# agentic AI systems can independently make decisions and execute tasks across dynamic environments. This report
# explores the significance of agentic AI, detailing its core principles, design patterns, and frameworks that enable
# its development. It also examines real-world applications across various industries and addresses the challenges
# faced in implementing these systems. The purpose of this report is to provide a comprehensive understanding of
# agentic AI and its potential to revolutionize industries by enhancing operational efficiency and decision-making.
#
#
#                                              Understanding Agentic AI
#
# Agentic AI represents a significant evolution in artificial intelligence, characterized by its autonomy,
# adaptability, and goal-oriented behavior. Unlike traditional AI, which operates within predefined constraints,
# agentic AI systems can independently make decisions and execute tasks across dynamic environments. This capability
# is achieved through a combination of sophisticated reasoning, iterative planning, and continuous learning from
# interactions. For instance, NVIDIA's agentic AI systems autonomously solve complex, multi-step problems by
# integrating data from various sources and adapting to new information in real-time.
#
# Agentic AI differs from traditional AI in several key aspects:
#
#  • Autonomy: Operates independently without constant human oversight.
#  • Adaptability: Learns from interactions and adjusts strategies based on feedback.
#  • Goal Orientation: Pursues specific objectives, optimizing actions to achieve desired outcomes.
#
# A practical example is Amazon's use of agentic AI in its warehouses, which has led to a 30% reduction in processing
# time and a 25% increase in order fulfillment accuracy. This demonstrates the transformative potential of agentic AI
# in enhancing operational efficiency and decision-making across industries.
#
#                                                       Sources
#
#  • What Is Agentic AI? - NVIDIA Blog: https://blogs.nvidia.com/blog/what-is-agentic-ai/
#  • Agentic AI vs. Traditional AI - KYP.ai: https://kyp.ai/agentic-ai-when-to-choose-agentic-ai-over-traditional-ai/
#  • Agentic AI: Nine Essential Questions - MIT Sloan Management Review:
#    https://sloanreview.mit.edu/article/agentic-ai-nine-essential-questions/
#
#
#                                            Design Patterns in Agentic AI
#
# Agentic AI systems leverage design patterns to manage complexity and enhance scalability, particularly in
# multi-agent setups. These patterns are crucial for structuring AI systems that can operate autonomously and
# adaptively. In single-agent systems, patterns like the ReAct (Reasoning and Acting) pattern allow an AI to
# alternate between reasoning and actions, optimizing tool-augmented thinking. For instance, a support bot using
# ReAct can interpret queries, search for information, and provide answers dynamically.
#
# In contrast, multi-agent systems utilize more complex patterns such as the Orchestrator pattern, where a central
# agent coordinates specialized agents to complete tasks. A case study in finance demonstrates this: an orchestrator
# agent manages database, analysis, graph, and report agents to generate financial reports efficiently. This modular
# approach enhances system resilience and task execution speed.
#
# Multi-agent systems are particularly beneficial in environments requiring parallel processing and dynamic task
# allocation, such as smart cities or autonomous vehicles. These systems distribute intelligence across agents,
# allowing for robust, scalable solutions that single-agent systems cannot achieve alone.
#
#                                                       Sources
#
#  • AI Agent Architecture: Core Principles & Tools in 2025: https://orq.ai/blog/ai-agent-architecture
#  • When One AI Agent Isn't Enough -Building Multi-Agent Systems:
#    https://medium.com/@nirdiamant21/when-one-ai-agent-isnt-enough-building-multi-agent-systems-755479f2c64d
#  • Single Agent vs Multi Agent AI: Which Is Better?: https://www.kubiya.ai/blog/single-agent-vs-multi-agent-in-ai
#
#
#                                     Frameworks for Building Agentic AI Systems
#
# Agentic AI frameworks are revolutionizing AI development by enabling autonomous, context-aware, and goal-directed
# behavior. These frameworks, such as LangGraph, AutoGen, and CrewAI, provide the infrastructure for building systems
# where agents can plan, reason, and collaborate. LangGraph and AutoGen are particularly noted for their multi-agent
# capabilities, allowing agents to delegate tasks and interact with enterprise tools securely. CrewAI, on the other
# hand, supports role-based agent design and message coordination, offering flexibility for both new builds and
# existing AI workflows.
#
# A specific example is Amazon's use of agentic frameworks to develop personalized product recommendation systems,
# showcasing the practical application of these frameworks in enhancing customer experience. The frameworks' ability
# to integrate with large language models (LLMs) and other tools makes them suitable for complex, dynamic
# environments.
#
#                                                       Sources
#
#  • Top Agentic AI Tools in 2025: Key Features, Use Cases & Risks: https://www.lasso.security/blog/agentic-ai-tools
#  • Agentic AI Frameworks: Architectures, Protocols, and Design ... - arXiv: https://arxiv.org/html/2508.10146v1
#  • Top 10 Open-Source Agentic Framework Tools to Revolutionize ...:
#    https://superagi.com/top-10-open-source-agentic-framework-tools-to-revolutionize-your-development-in-2024/
#
#
#                                        Real-World Applications of Agentic AI
#
# Agentic AI is revolutionizing industries by enabling autonomous decision-making and dynamic adaptation. In
# healthcare, Agentic AI systems enhance diagnostics and patient care. For instance, AI agents in hospitals can
# autonomously manage patient data, predict disease progression, and optimize treatment plans, reducing sepsis deaths
# by 17% in a study of 6,000 cases [Nature Medicine]. In finance, Agentic AI systems are transforming fraud detection
# by autonomously monitoring transactions and adapting to new fraud patterns, reducing false positives and enhancing
# security [McKinsey]. In logistics, AI agents optimize supply chains by autonomously adjusting routes and managing
# inventory, leading to a 30% improvement in forecast accuracy and a 40% increase in SLA adherence for deliveries
# [BCG]. These examples illustrate the transformative potential of Agentic AI across various sectors, driving
# efficiency and innovation.
#
#                                                       Sources
#
#  • Agentic AI Examples: Real-World Applications of Autonomous Agents:
#    https://quantiphi.com/blog/agentic-ai-examples-real-world-applications-of-autonomous-agents
#  • Agentic AI in Action: Industries, Real-World Applications, and What's Next:
#    https://ascendion.com/insights/agentic-ai-in-action-industries-real-world-applications-and-whats-next/
#  • The State of AI: Global Survey 2025 - McKinsey:
#    https://www.mckinsey.com/capabilities/quantumblack/our-insights/the-state-of-ai
#  • 8 Real-World Examples of Agentic AI: From Hype to Measurable Results:
#    https://quixy.com/blog/examples-of-agentic-ai/
#
#
#                               Challenges and Considerations in Agentic AI Development
#
# Agentic AI systems face significant challenges in implementation, primarily due to infrastructure and data
# foundation gaps. According to Gartner, by 2028, 15% of work decisions will be autonomously made by agentic AI,
# highlighting the need for robust infrastructure. However, 65% of companies lack the foundational infrastructure
# necessary for effective agentic AI deployment, as noted by Lucidworks. This gap can lead to decision errors and
# cascading risks, as explained by Murray from Reworked.
#
# Key challenges include:
#
#  • Infrastructure and Data Foundation Gaps: Many organizations attempt to deploy agentic AI without adequate
#    infrastructure, leading to failures.
#  • Misaligned Expectations and ROI Challenges: Companies often underestimate the resources needed for successful AI
#    deployment, leading to unclear ROI.
#  • Risk Management and Governance Inadequacies: The autonomous nature of agentic AI introduces new risk categories
#    that require sophisticated governance frameworks.
#
# For example, Hitachi Digital's implementation of agentic AI in HR operations demonstrates the need for clear
# business logic and contextual data to manage data silos effectively.
#
#                                                       Sources
#
#  • Why Agentic AI Projects Fail: https://www.reworked.co/digital-workplace/why-agentic-ai-projects-fail/
#  • Agentic AI: The Top 5 Challenges and How to Overcome Them:
#    https://www.confluent.io/blog/agentic-ai-the-top-5-challenges-and-how-to-overcome-them/
#
#
#                                                     Conclusion
#
# This report has explored the transformative potential of Agentic AI, highlighting its autonomy, adaptability, and
# goal-oriented behavior. Unlike traditional AI, Agentic AI systems operate independently, learning from interactions
# and optimizing actions to achieve specific objectives. The design patterns, such as ReAct and Orchestrator, enable
# these systems to manage complexity and enhance scalability, particularly in multi-agent setups. Frameworks like
# LangGraph and AutoGen facilitate the development of these systems, allowing for dynamic, context-aware operations
# across industries. Real-world applications demonstrate significant improvements in efficiency and innovation, from
# healthcare to logistics. However, challenges such as infrastructure gaps and governance inadequacies must be
# addressed for successful implementation.
#
#
#   Aspect                    Key Insights
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Autonomy                  Operates independently, reducing need for constant human oversight
#   Design Patterns           ReAct and Orchestrator patterns enhance scalability and task execution
#   Frameworks                LangGraph and AutoGen support dynamic, context-aware operations
#   Real-World Applications   Significant improvements in efficiency across industries
#   Challenges                Infrastructure gaps and governance issues need addressing for success
#
#
# The next steps involve addressing these challenges to fully harness the potential of Agentic AI.

# %%
topic = "Detailed report on how is NVIDIA winning the game against its competitors"
await call_planner_agent(agent=reporter_agent,
                         prompt=topic)
# Out:
# --- Generating Report Plan ---
# --- Generating Report Plan Completed ---
# --- Generating Search Queries for Section: Sustainability and Corporate Responsibility ---
# --- Generating Search Queries for Section: NVIDIA's Market Dominance ---
# --- Generating Search Queries for Section: Strategic Partnerships and Acquisitions ---
# --- Generating Search Queries for Section: Developer Ecosystem and Software Integration ---
# --- Generating Search Queries for Section: Technological Innovations and Product Diversification ---
# --- Generating Search Queries for Section: Sustainability and Corporate Responsibility Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: NVIDIA's Market Dominance Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Strategic Partnerships and Acquisitions Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Technological Innovations and Product Diversification Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Developer Ecosystem and Software Integration Completed ---
# --- Searching Web for Queries ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Sustainability and Corporate Responsibility ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Strategic Partnerships and Acquisitions ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : NVIDIA's Market Dominance ---
# --- Searching Web for Queries Completed ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Developer Ecosystem and Software Integration ---
# --- Writing Section : Technological Innovations and Product Diversification ---
# --- Writing Section : Sustainability and Corporate Responsibility Completed ---
# --- Writing Section : NVIDIA's Market Dominance Completed ---
# --- Writing Section : Technological Innovations and Product Diversification Completed ---
# --- Writing Section : Strategic Partnerships and Acquisitions Completed ---
# --- Writing Section : Developer Ecosystem and Software Integration Completed ---
# --- Formatting Completed Sections ---
# --- Formatting Completed Sections is Done ---
# --- Writing Final Section: Introduction ---
# --- Writing Final Section: Conclusion ---
# --- Writing Final Section: Introduction Completed ---
# --- Writing Final Section: Conclusion Completed ---
# --- Compiling Final Report ---
# --- Compiling Final Report Done ---
# ==================================================
# Final Report:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                  Introduction                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# NVIDIA stands as a formidable leader in the technology market, particularly in the GPU and AI chip sectors. With a
# commanding 94% share of the discrete GPU market, NVIDIA has outpaced competitors like AMD and Intel, largely due to
# its strategic focus on AI and gaming. The company's technological innovations, such as the Blackwell architecture,
# and strategic acquisitions have further solidified its position. NVIDIA's robust developer ecosystem, driven by
# CUDA, enhances its hardware offerings, making it a preferred choice for AI applications. As NVIDIA continues to
# innovate and expand its reach, it remains a pivotal force in the evolving tech landscape.
#
#
#                                              NVIDIA's Market Dominance
#
# NVIDIA commands an overwhelming 94% of the discrete GPU market as of Q2 2025, leaving AMD and Intel far behind.
# According to Jon Peddie Research, NVIDIA's market share in the add-in-board GPU segment has surged, with AMD's
# share dwindling to 6% and Intel's presence nearly nonexistent. This dominance is attributed to NVIDIA's strategic
# focus on AI and gaming sectors, bolstered by the release of the RTX 50 series GPUs. Despite AMD's competitive
# pricing and new product launches, it has struggled to maintain its market position. NVIDIA's success is further
# amplified by its CUDA platform, which enhances GPU performance for AI applications, making it the preferred choice
# for data centers and AI research. The company's recent acquisition of Run:ai aims to strengthen its AI
# infrastructure capabilities, ensuring continued leadership in the AI chip market. As NVIDIA continues to innovate,
# its competitors face significant challenges in closing the gap.
#
#                                                       Sources
#
#  • Nvidia Grows to 94% of GPU Market, Intel's Share Hits 0%:
#    https://www.extremetech.com/computing/nvidia-grows-to-94-of-gpu-market-intels-share-hits-0
#  • NVIDIA's Discrete GPU Market Share Swells To 94%, AMD Drops To ...:
#    https://wccftech.com/nvidia-gpu-market-share-swells-to-94-percent-amd-drops-to-6-in-q2-2025/
#
#
#                                Technological Innovations and Product Diversification
#
# NVIDIA's Blackwell architecture, introduced in 2024, marks a significant leap in GPU performance, delivering up to
# 30 times greater inference performance while consuming 25 times less energy compared to its predecessor, Hopper.
# This architecture is pivotal for generative AI and data processing tasks, with the B100 and B200 models leading the
# charge. NVIDIA's dominance in the GPU market is underscored by its 90% market share and $30 billion revenue in Q2
# 2024, driven by data center demand for AI workloads. Beyond gaming, NVIDIA's GPUs are integral to data centers and
# automotive sectors, powering AI-driven manufacturing and autonomous vehicle technologies. For instance, General
# Motors utilizes NVIDIA's Omniverse platform to create digital twins of assembly lines, enhancing production
# efficiency. NVIDIA's AI capabilities extend to automotive safety and self-driving technologies, as seen in
# collaborations with companies like Mercedes-Benz. The company's strategic focus on AI infrastructure and continuous
# innovation ensures its leadership in the evolving tech landscape.
#
#                                                       Sources
#
#  • Revolution of GPU in 2024: A Recap: https://blog.neevcloud.com/revolution-of-gpu-in-2024-a-recap
#  • Nvidia showcases automotive partners and generative AI for robotics:
#    https://venturebeat.com/ai/nvidia-showcases-automotive-partners-and-generatie-ai-for-robotics
#  • GM turns to Nvidia for AI-driven manufacturing and automation:
#    https://news.dealershipguy.com/p/gm-turns-to-nvidia-for-ai-driven-manufacturing-and-automation-2025-03-19
#
#
#                                       Strategic Partnerships and Acquisitions
#
# NVIDIA's strategic partnerships and acquisitions have significantly bolstered its market position and expanded its
# technological capabilities. A prime example is the acquisition of Mellanox Technologies in 2020 for $6.9 billion.
# This acquisition integrated Mellanox's high-performance networking solutions with NVIDIA's GPUs, creating an
# end-to-end data center solution that enhanced AI workloads by improving data movement efficiency. This synergy has
# been pivotal in NVIDIA's rise in the data center market, with its networking business now generating over $10
# billion in revenue.
#
# NVIDIA's partnerships also play a crucial role in its strategy. Collaborations with companies like Microsoft and
# Google Cloud have enabled NVIDIA to offer its DGX Cloud and Omniverse Cloud services, providing scalable AI
# solutions. These partnerships leverage NVIDIA's advanced GPU technology to enhance cloud-based AI applications,
# further solidifying its leadership in AI infrastructure.
#
#  • Key Acquisitions:
#     • Mellanox Technologies: $6.9 billion (2020)
#     • Cumulus Networks: Networking software
#     • Bright Computing: Management software
#
# These strategic moves have positioned NVIDIA as a leader in AI and accelerated computing, driving innovation and
# growth across various sectors.
#
#                                                       Sources
#
#  • NVIDIA to Acquire Mellanox for $6.9 Billion:
#    http://nvidianews.nvidia.com/news/nvidia-to-acquire-mellanox-for-6-9-billion
#  • NVIDIA's $10B+ Revenue Networking Business:
#    https://www.datagravity.dev/p/nvidias-10b-revenue-networking-business
#  • NVIDIA's Data Center Platform Play Unveiled At GTC 2023:
#    https://www.forbes.com/sites/stevemcdowell/2023/03/22/nvidias-data-center-platform-play-unveiled-at-gtc-2023/
#
#
#                                    Developer Ecosystem and Software Integration
#
# NVIDIA's developer ecosystem, bolstered by CUDA, is a cornerstone of its dominance in AI and accelerated computing.
# With over 5 million developers and 40,000 companies engaged, NVIDIA's ecosystem is vast and influential. CUDA,
# introduced in 2006, has become a standard for parallel computing, offering over 300 libraries and 3,500
# GPU-accelerated applications. This extensive support has led to more than 48 million downloads, highlighting its
# widespread adoption. CUDA's integration with AI frameworks like TensorFlow and PyTorch ensures optimized
# performance, making it indispensable for deep learning tasks. For instance, NVIDIA's GPUs, powered by CUDA, have
# been pivotal in training large language models, achieving performance levels that would require thousands of CPUs.
# This integration not only accelerates AI development but also reduces energy consumption significantly. NVIDIA's
# continuous innovation, such as the introduction of CUDA-X libraries, further expands its reach into new markets,
# from healthcare to telecommunications. This robust ecosystem, combined with NVIDIA's hardware advancements,
# positions it as a leader in the AI revolution.
#
#                                                       Sources
#
#  • NVIDIA 2024 Annual Review:
#    https://s201.q4cdn.com/141608511/files/doc_financials/2024/ar/NVIDIA-2024-Annual-Report.pdf
#  • NVIDIA Technical Blog:
#    https://developer.nvidia.com/blog/boosting-cuda-efficiency-with-essential-techniques-for-new-developers/
#  • Medium Article on CUDA:
#    https://medium.com/@aidanpak/the-cuda-advantage-how-nvidia-came-to-dominate-ai-and-the-role-of-gpu-memory-in-lar
#    ge-scale-model-e0cdb98a14a0
#
#
#                                     Sustainability and Corporate Responsibility
#
# NVIDIA's commitment to sustainability is exemplified by its ambitious goal to achieve net-zero emissions for Scope
# 1 and 2 by 2025. The company has aligned with the Science-Based Targets initiative (SBTi) and is actively
# addressing Scope 3 emissions, which constitute the majority of its environmental impact. NVIDIA's GPUs, such as the
# Blackwell architecture, are designed to be highly energy-efficient, offering up to 50x more efficiency than
# traditional CPUs for AI inference workloads. This efficiency is crucial as data centers, which are responsible for
# 1-2% of global electricity consumption, continue to grow.
#
# NVIDIA's sustainability strategy includes:
#
#  • 100% Renewable Energy: Achieved in U.S. operations, with plans to expand globally.
#  • Supplier Engagement: Over 80% of suppliers are engaged in reducing emissions.
#  • Innovative Technologies: The Earth-2 platform for climate modeling and Omniverse for digital twins help
#    industries optimize operations and reduce emissions.
#
# NVIDIA's efforts are not without challenges, particularly in managing Scope 3 emissions and enhancing product
# recyclability. However, its focus on energy-efficient computing and renewable energy adoption positions it as a
# leader in sustainable technology.
#
#                                                       Sources
#
#  • NVIDIA Sustainability: https://thesustainableinnovation.com/nvidia/
#  • NVIDIA Corporate Responsibility Report FY2024:
#    https://images.nvidia.com/aem-dam/Solutions/documents/FY2024-NVIDIA-Corporate-Sustainability-Report.pdf
#  • Sustainable Computing Solutions | NVIDIA: https://www.nvidia.com/en-us/data-center/sustainable-computing/
#
#
#                                                     Conclusion
#
# NVIDIA's sustained market dominance is a result of its strategic focus on technological innovation, strategic
# partnerships, and a robust developer ecosystem. The company's Blackwell architecture has revolutionized GPU
# performance, significantly enhancing AI and data processing capabilities. Strategic acquisitions, such as Mellanox
# Technologies, have bolstered NVIDIA's data center solutions, while partnerships with tech giants like Microsoft and
# Google Cloud have expanded its AI infrastructure reach. The CUDA platform remains a cornerstone, driving widespread
# adoption and integration with leading AI frameworks. NVIDIA's commitment to sustainability, with goals like
# achieving net-zero emissions, further solidifies its leadership position.
#
#
#   Key Factors          NVIDIA                         Competitors (AMD, Intel)
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Market Share         94% in discrete GPU            6% (AMD), negligible (Intel)
#   Technological Edge   Blackwell architecture, CUDA   Limited AI focus
#   Strategic Moves      Acquisitions, partnerships     Less impactful collaborations
#   Sustainability       Net-zero by 2025               Less defined goals
#
#
# NVIDIA's strategic initiatives ensure its continued leadership in the tech industry, setting a benchmark for
# innovation and sustainability.

# %%
topic = "Detailed report on how DeepSeek has disrupted the AI Market"
await call_planner_agent(agent=reporter_agent,
                         prompt=topic)
# Out:
# --- Generating Report Plan ---
# --- Generating Report Plan Completed ---
# --- Generating Search Queries for Section: DeepSeek's Market Disruption ---
# --- Generating Search Queries for Section: Challenges and Controversies ---
# --- Generating Search Queries for Section: Impact on AI Competition and Innovation ---
# --- Generating Search Queries for Section: Real-World Applications and Case Studies ---
# --- Generating Search Queries for Section: Technological Innovations of DeepSeek ---
# --- Generating Search Queries for Section: Real-World Applications and Case Studies Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Impact on AI Competition and Innovation Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Challenges and Controversies Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: DeepSeek's Market Disruption Completed ---
# --- Searching Web for Queries ---
# --- Generating Search Queries for Section: Technological Innovations of DeepSeek Completed ---
# --- Searching Web for Queries ---
# --- Searching Web for Queries Completed ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : DeepSeek's Market Disruption ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Impact on AI Competition and Innovation ---
# --- Writing Section : Challenges and Controversies ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Real-World Applications and Case Studies ---
# --- Writing Section : Impact on AI Competition and Innovation Completed ---
# --- Writing Section : Challenges and Controversies Completed ---
# --- Writing Section : DeepSeek's Market Disruption Completed ---
# --- Writing Section : Real-World Applications and Case Studies Completed ---
# --- Searching Web for Queries Completed ---
# --- Writing Section : Technological Innovations of DeepSeek ---
# --- Writing Section : Technological Innovations of DeepSeek Completed ---
# --- Formatting Completed Sections ---
# --- Formatting Completed Sections is Done ---
# --- Writing Final Section: Introduction ---
# --- Writing Final Section: Conclusion ---
# --- Writing Final Section: Introduction Completed ---
# --- Writing Final Section: Conclusion Completed ---
# --- Compiling Final Report ---
# --- Compiling Final Report Done ---
# ==================================================
# Final Report:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                  Introduction                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# DeepSeek has emerged as a transformative force in the AI market, challenging established norms with its
# cost-efficient and high-performance models. By leveraging innovative architectures like Mixture-of-Experts and
# adopting an open-source approach, DeepSeek has not only disrupted financial markets but also redefined competitive
# dynamics among tech giants. This report delves into DeepSeek's technological advancements, its impact on AI
# competition, and real-world applications, while also addressing the challenges and controversies it faces. Through
# this exploration, we aim to understand DeepSeek's role in shaping the future of AI and its broader implications for
# the industry.
#
#
#                                            DeepSeek's Market Disruption
#
# DeepSeek has significantly disrupted the global AI market by demonstrating that high-performance AI models can be
# developed at a fraction of the cost of their Western counterparts. The launch of DeepSeek's R1 model on January 27,
# 2025, led to a $1 trillion loss in U.S. stock markets, with Nvidia alone losing $500 billion in market
# capitalization. This event highlighted the potential of cost-efficient AI models to challenge established tech
# giants like OpenAI and Google. DeepSeek's R1 model, developed for under $6 million, utilizes a Mixture-of-Experts
# architecture, enabling efficient performance with fewer computational resources. This approach contrasts sharply
# with the $100 million spent on training models like OpenAI's GPT-4.
#
#  • Key Impacts:
#     • Financial Markets: The R1 model's release caused significant volatility, underscoring the market's
#       sensitivity to AI advancements.
#     • Tech Giants: Companies like Nvidia and Broadcom experienced substantial stock declines, prompting a
#       reevaluation of AI investment strategies.
#     • Competitive Landscape: DeepSeek's open-source model challenges the proprietary nature of Western AI,
#       promoting broader access and innovation.
#
#                                                       Sources
#
#  • Deep Dive: Exploring Deep Seek's Implications on AI Market and Future for Technology:
#    https://www.queensbusinessreview.com/articles/9pggtv21hrrciuqtbkw9bil0xobkq0
#  • What’s next for artificial intelligence after DeepSeek?:
#    https://www.invesco.com/us/en/insights/ai-after-deepseek.html
#  • DeepSeek's Disruption of Global Financial Markets: What You Need to Know:
#    https://blueberrymarkets.com/market-analysis/deepseeks-disruption-of-global-financial-markets-what-you-need-to-k
#    now/
#
#
#                                        Technological Innovations of DeepSeek
#
# DeepSeek's technological advancements have redefined AI model efficiency and accessibility. The DeepSeek-V3 model,
# with its 671 billion parameters, utilizes a Mixture-of-Experts (MoE) architecture, activating only 37 billion
# parameters per token, significantly reducing computational costs. This architecture, combined with Multi-head
# Latent Attention (MLA), enhances memory efficiency and inference speed. DeepSeek's training innovations include FP8
# mixed precision, which reduces GPU memory usage by 30% and accelerates training by 2.1 times, completing
# pre-training in just 2.788 million H800 GPU hours. This efficiency is achieved through a co-design of algorithms,
# frameworks, and hardware, allowing DeepSeek to offer competitive performance at a fraction of the cost of its
# peers.
#
#  • Cost Efficiency: Training DeepSeek-V3 costs approximately $5.6 million, significantly lower than comparable
#    models like GPT-4o.
#  • Open-Source Approach: DeepSeek's models are open-source, promoting community-driven development and eliminating
#    licensing fees.
#  • Real-World Application: DeepSeek's models are used in diverse sectors, from healthcare diagnostics to urban
#    planning, demonstrating their versatility and impact.
#
#                                                       Sources
#
#  • DeepSeek-V3 Technical Report: https://arxiv.org/html/2412.19437v1
#  • All About DeepSeek — The Chinese AI Startup Challenging US Big Tech:
#    https://www.forbes.com/sites/janakirammsv/2025/01/26/all-about-deepseekthe-chinese-ai-startup-challenging-the-us
#    -big-tech/
#  • DeepSeek's Low Inference Cost Explained: MoE & Strategy:
#    https://intuitionlabs.ai/articles/deepseek-inference-cost-explained
#
#
#                                       Impact on AI Competition and Innovation
#
# DeepSeek's emergence has significantly shifted the AI landscape towards open-source models, challenging traditional
# AI providers. Released in January 2025, DeepSeek-R1 outperformed leading models like OpenAI's o1 on several
# benchmarks, including math and reasoning, while maintaining cost efficiency. DeepSeek's open-source approach,
# exemplified by its MIT-licensed models, has democratized AI development, enabling broader access and collaboration.
# This shift is evident in the rapid adoption of DeepSeek models, with downloads increasing nearly 1000% since their
# release.
#
# DeepSeek's strategy of optimizing software over hardware reliance, as noted by Marina Zhang, has allowed it to
# thrive despite U.S. export controls on advanced chips. The company's focus on software-driven resource optimization
# and open-source collaboration has set a new standard for AI development, emphasizing efficiency and accessibility
# over sheer computational power. This approach not only challenges the dominance of proprietary models but also
# fosters innovation by lowering entry barriers for researchers and startups globally.
#
#                                                       Sources
#
#  • How Chinese AI Startup DeepSeek Made a Model that Rivals OpenAI:
#    https://www.wired.com/story/deepseek-china-model-ai/
#  • How Deepseek is Changing the AI Landscape:
#    https://news.gsu.edu/2025/02/04/how-deepseek-is-changing-the-a-i-landscape/
#  • AI Disruption at Scale: DeepSeek's Open-Source Model and Its Macroeconomic Impact:
#    https://academiainsight.com/index.php/ijbmfr/article/download/398/209/457
#
#
#                                      Real-World Applications and Case Studies
#
# DeepSeek R1 is revolutionizing healthcare by making AI more accessible and cost-effective. The open-source nature
# of DeepSeek R1, released in January 2025, allows smaller clinics and hospitals to leverage advanced AI without
# prohibitive costs. For instance, Akso Health Group has integrated DeepSeek’s language model to enhance medical
# consultations and diagnostics, processing lab results and medical imaging analyses efficiently. This model's
# ability to handle extensive contextual information enables it to process complex patient histories, paving the way
# for personalized medicine.
#
# DeepSeek R1's efficiency is evident in its training cost of approximately $5.6 million, significantly lower than
# competitors like OpenAI, which often require hundreds of millions. This cost-effectiveness is achieved through
# innovative architectural designs like Mixture-of-Experts (MoE) and multi-head latent attention mechanisms, reducing
# the computational burden. As a result, DeepSeek R1 operates on just 2,000 GPUs, compared to tens of thousands
# typically required by other models, making it a sustainable AI solution.
#
#                                                       Sources
#
#  • The Role Of DeepSeek In Healthcare And Associated Challenges:
#    https://spsoft.com/tech-insights/the-impact-of-deepseek-in-healthcare/
#  • DeepSeek AI: What Does It Mean For Healthcare?:
#    https://medicalfuturist.com/deepseek-ai-what-does-it-mean-for-healthcare/
#
#
#                                            Challenges and Controversies
#
# DeepSeek faces significant regulatory, ethical, and competitive challenges. The U.S. government has banned
# DeepSeek's AI models in federal agencies like the Navy and NASA due to national security concerns, particularly
# regarding data privacy and potential manipulation (Lexology, 2025). Italy and Belgium have also launched
# investigations into DeepSeek's data practices, citing inadequate data protection and cross-border transfer issues
# (Lexology, 2025). These regulatory hurdles are compounded by ethical concerns over DeepSeek's data collection
# policies, which lack transparency and may involve unauthorized data usage (Carleton, 2025). Additionally,
# DeepSeek's competitive strategy of offering cost-efficient models has disrupted the AI market, challenging
# established players like OpenAI and Google to lower prices or enhance offerings (Forbes, 2025). Despite these
# challenges, DeepSeek's innovative techniques, such as reinforcement learning and mixture-of-experts architecture,
# have positioned it as a formidable competitor in the AI landscape (arXiv, 2025).
#
#                                                       Sources
#
#  • DeepSeek Faces Oversea and Chinese Data Security Challenges:
#    https://www.lexology.com/library/detail.aspx?g=e98373d5-d7ac-4b81-9958-b42a6d5ddbed
#  • Think Twice Before Using DeepSeek: Security and Trust Issues Explained:
#    https://www.carleton.edu/ai/blog/think-twice-before-using-deepseek-security-and-trust-issues-explained/
#  • All About DeepSeek — The Chinese AI Startup Challenging US Big Tech:
#    https://www.forbes.com/sites/janakirammsv/2025/01/26/all-about-deepseekthe-chinese-ai-startup-challenging-the-us
#    -big-tech/
#  • DeepSeek-R1: Incentivizing Reasoning Capability in LLMs via Reinforcement Learning:
#    https://arxiv.org/pdf/2501.12948
#
#
#                                                     Conclusion
#
# DeepSeek has emerged as a transformative force in the AI market, challenging established norms with its
# cost-efficient and open-source models. The launch of DeepSeek's R1 model disrupted financial markets, highlighting
# the potential of affordable AI solutions to rival tech giants like OpenAI and Google. Technologically, DeepSeek's
# Mixture-of-Experts architecture and innovative training methods have set new standards for efficiency and
# accessibility. The company's open-source approach has democratized AI development, fostering global collaboration
# and innovation.
#
# Despite facing regulatory and ethical challenges, DeepSeek's impact is undeniable, with its models being adopted
# across diverse industries, from healthcare to urban planning. As the AI landscape evolves, DeepSeek's emphasis on
# software-driven optimization and community engagement positions it as a key player in shaping the future of AI.
#
#  • Key Implications:
#     • Continued pressure on traditional AI providers to innovate and reduce costs.
#     • Potential for increased regulatory scrutiny and ethical considerations.
#     • Expansion of AI applications across various sectors, driven by accessible and efficient models.
