# %% [markdown]
# # Build a Customer Support Router Agentic RAG System
#
# In this project, we will leverage the power of AI Agents and RAG Systems to build an intelligent Router Agentic RAG System to handle customer support queries using a custom knowledgebase.
#
# ![](https://i.imgur.com/bLCdxCI.png)
#
# ### Intelligent Router Agentic RAG System
#
# This project focuses on building an **Intelligent Router Agentic RAG System** that combines intelligent query analysis, sentiment detection, and dynamic routing with Retrieval-Augmented Generation (RAG) to handle diverse user inquiries efficiently. The workflow includes the following components:
#
# 1. **Query Categorization and Sentiment Analysis**:
#    - The system uses **OpenAI GPT-4o** to analyze the user's query and determine:
#      - **Query Category**: Identifies the type of problem, such as billing, technical issues, or general queries.
#      - **User Sentiment**: Evaluates the user's sentiment (positive, neutral, or negative) to determine if escalation is needed.
#
# 2. **Intelligent Routing**:
#    - Based on the **query_category** and **query_sentiment**, the system routes the query to the appropriate handling node:
#      - **Escalate to Human**: If the sentiment is negative, the query is escalated to a human for resolution.
#      - **Generate Billing Response**: Queries related to billing are routed to generate an appropriate response.
#      - **Generate Technical Response**: Technical queries are routed for a specialized technical response.
#      - **Generate General Response**: General queries are handled with context-aware responses.
#
# 3. **Knowledge Base Integration (RAG)**:
#    - The system integrates with a **Knowledge Base (Vector Database)** to augment responses with relevant and accurate information.
#    - Retrieval-Augmented Generation (RAG) ensures that responses are grounded in the latest and most reliable data.
#
# 4. **Escalation Mechanism**:
#    - Negative sentiment triggers an **escalation to a human**, ensuring the user receives empathetic and personalized support for critical issues.

# %% [markdown]
# ## Install OpenAI, LangGraph and LangChain dependencies

# %%
# !pip install langchain==0.3.14
# !pip install langchain-openai==0.3.0
# !pip install langchain-community==0.3.14
# !pip install langgraph==0.2.64
# Out:
# Requirement already satisfied: langchain==0.3.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (3.13.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.3.63)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.3.8)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (0.1.147)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.12.4)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain==0.3.14) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14) (1.22.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain==0.3.14) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (3.11.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.14) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.14) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.14) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.14) (1.3.1)
# Requirement already satisfied: langchain-openai==0.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.3.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-openai==0.3.0) (0.3.63)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-openai==0.3.0) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-openai==0.3.0) (0.12.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (6.0.3)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (4.15.0)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2.12.4)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (3.11.4)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.0) (0.12.0)
# Requirement already satisfied: sniffio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.0) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4.0,>=0.3.29->langchain-openai==0.3.0) (2.3.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.0) (2025.11.3)
# Requirement already satisfied: langchain-community==0.3.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.4.3)
# Requirement already satisfied: langchain<0.4.0,>=0.3.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.3.14)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.3.63)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (0.1.147)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (2.11.0)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-community==0.3.14) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.14) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community==0.3.14) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community==0.3.14) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community==0.3.14) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain-community==0.3.14) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (3.11.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community==0.3.14) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.14) (1.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.14) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.14) (2.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.14) (1.3.1)
# Requirement already satisfied: langgraph==0.2.64 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.2.64)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.64) (0.3.63)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.64) (2.1.2)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph==0.2.64) (0.1.74)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (6.0.3)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (4.15.0)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (2.12.4)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph==0.2.64) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (3.11.4)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph==0.2.64) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.64) (1.3.1)

# %%
# !pip install langchain-chroma==0.2.0
# Out:
# Requirement already satisfied: langchain-chroma==0.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (0.2.0)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-chroma==0.2.0) (0.5.23)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-chroma==0.2.0) (0.120.4)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-chroma==0.2.0) (0.3.63)
# Requirement already satisfied: numpy<2.0.0,>=1.26.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-chroma==0.2.0) (1.26.4)
# Requirement already satisfied: build>=1.0.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2.12.4)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.35.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (7.0.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.59b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.38.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (14.2.0)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from fastapi<1,>=0.95.2->langchain-chroma==0.2.0) (0.49.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from fastapi<1,>=0.95.2->langchain-chroma==0.2.0) (0.0.4)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.0) (0.1.147)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.0) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.0) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.0) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.0) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.0) (1.0.0)
# Requirement already satisfied: anyio in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (4.11.0)
# Requirement already satisfied: certifi in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.0.9)
# Requirement already satisfied: idna in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.0) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.36.0)
# Requirement already satisfied: filelock in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.2.0)
# Requirement already satisfied: pyproject_hooks in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.2.0)
# Requirement already satisfied: six>=1.9.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.6.1)
# Requirement already satisfied: coloredlogs in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (25.9.23)
# Requirement already satisfied: protobuf in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (6.33.1)
# Requirement already satisfied: sympy in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.59b0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.59b0)
# Requirement already satisfied: opentelemetry-util-http==0.59b0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.59b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.17.3)
# Requirement already satisfied: asgiref~=3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from opentelemetry-instrumentation-asgi==0.59b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (3.10.0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.0.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma==0.2.0) (1.3.0)

# %% [markdown]
# ## Enter Open AI API Key

# %%
from getpass import getpass

OPENAI_KEY = getpass('Enter Open AI API Key: ')

# %% [markdown]
# ## Setup Environment Variables

# %%
import os

os.environ['OPENAI_API_KEY'] = OPENAI_KEY

# %% [markdown]
# ## Load Company Knowledge Base

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from gdown) (4.14.2)
# Requirement already satisfied: filelock in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tqdm in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/soumil/yes/envs/notebooks/lib/python3.13/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
# or download manually from https://drive.google.com/file/d/1CWHutosAcJ6fiddQW5ogvg7NgLstZJ9j/view?usp=sharing and upload to colab or your notebook location
# !gdown 1CWHutosAcJ6fiddQW5ogvg7NgLstZJ9j
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CWHutosAcJ6fiddQW5ogvg7NgLstZJ9j
# To: /Users/soumil/Downloads/notebooks/router_agent_documents.json
# 100%|██████████████████████████████████████| 7.99k/7.99k [00:00<00:00, 8.03MB/s]

# %%
import json

with open("./router_agent_documents.json", "r") as f:
    knowledge_base = json.load(f)

knowledge_base[:1]
# Out:
# [{'text': 'Question: How do I integrate your AI product with my existing CRM system? Answer: You can integrate our AI product with your CRM using our API. Refer to the API documentation available on our website for step-by-step guidance.',
#   'metadata': {'category': 'technical'}}]

# %%
knowledge_base[-1:]
# Out:
# [{'text': 'Question: What is your policy for handling damaged hardware deliveries? Answer: If you receive damaged hardware, please report it within 48 hours to our support team. We will arrange for a replacement.',
#   'metadata': {'category': 'general'}}]

# %%
from langchain.docstore.document import Document
from tqdm import tqdm

processed_docs = []

for doc in tqdm(knowledge_base):
    metadata = doc['metadata']
    data = doc['text']
    processed_docs.append(Document(page_content=data,
                                   metadata=metadata))

processed_docs[:3]
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 93137.76it/s]
# [Document(metadata={'category': 'technical'}, page_content='Question: How do I integrate your AI product with my existing CRM system? Answer: You can integrate our AI product with your CRM using our API. Refer to the API documentation available on our website for step-by-step guidance.'),
#  Document(metadata={'category': 'technical'}, page_content='Question: What programming languages are supported by your SDK? Answer: Our SDK supports Python, Java, and JavaScript. Additional language support is planned for future updates.'),
#  Document(metadata={'category': 'technical'}, page_content='Question: Can your AI models run on-premise? Answer: Yes, our AI models can be deployed on-premise. We provide deployment guides for various environments.')]

# %% [markdown]
# ## Create Vector Database

# %%
from langchain_openai import OpenAIEmbeddings

# details here: https://openai.com/blog/new-embedding-models-and-api-updates
openai_embed_model = OpenAIEmbeddings(model='text-embedding-3-small')

# %%
from langchain_chroma import Chroma

kbase_db = Chroma.from_documents(documents=processed_docs,
                                  collection_name='knowledge_base',
                                  embedding=openai_embed_model,
                                  # need to set the distance function to cosine else it uses euclidean by default
                                  # check https://docs.trychroma.com/guides#changing-the-distance-function
                                  collection_metadata={"hnsw:space": "cosine"},
                                  persist_directory="./knowledge_base")
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
kbase_search = kbase_db.as_retriever(search_type="similarity_score_threshold",
                                     search_kwargs={"k": 3, "score_threshold": 0.2})

# %%
query = 'what is your refund policy?'
metadata_filter = {'category' : 'general'}
# Update retriever search_kwargs dynamically
kbase_search.search_kwargs["filter"] = metadata_filter
kbase_search.invoke(query)
# Out:
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# [Document(id='0d9b72cf-1be7-490c-a99b-8174574eb69b', metadata={'category': 'general'}, page_content='Question: What is your refund policy? Answer: We offer a 30-day money-back guarantee for all our products. Please contact support to initiate a refund.'),
#  Document(id='bc06c8f0-0390-4c3d-a147-2a93cdacfce5', metadata={'category': 'general'}, page_content='Question: What is your refund policy? Answer: We offer a 30-day money-back guarantee for all our products. Please contact support to initiate a refund.'),
#  Document(id='593164e1-8c6b-4762-b174-5d84c0bc500a', metadata={'category': 'general'}, page_content='Question: What is your refund policy? Answer: We offer a 30-day money-back guarantee for all our products. Please contact support to initiate a refund.')]

# %%
query = 'what is your refund policy'
metadata_filter = {'category' : 'General'}
# Update retriever search_kwargs dynamically
kbase_search.search_kwargs["filter"] = metadata_filter
kbase_search.invoke(query)
# Out:
# No relevant docs were retrieved using the relevance score threshold 0.2
# []

# %%
query = 'what is your refund policy'
metadata_filter = {'category' : 'technical'}
# Update retriever search_kwargs dynamically
kbase_search.search_kwargs["filter"] = metadata_filter
kbase_search.invoke(query)
# Out:
# No relevant docs were retrieved using the relevance score threshold 0.2
# []

# %% [markdown]
# ## Define the Customer Inquiry State
#
# We create a `CustomerSupportState` typed dictionary to keep track of each interaction:
# - **customer_query**: The text of the customer's question
# - **query_category**: Technical, Billing, or General (used for routing)
# - **query_sentiment**: Positive, Neutral, or Negative (used for routing)
# - **final_response**: The system's response to the customer

# %%
from typing import TypedDict, Literal
from pydantic import BaseModel

class CustomerSupportState(TypedDict):
    customer_query: str
    query_category: str
    query_sentiment: str
    final_response: str

class QueryCategory(BaseModel):
    categorized_topic: Literal['Technical', 'Billing', 'General']

class QuerySentiment(BaseModel):
    sentiment: Literal['Positive', 'Neutral', 'Negative']

# %% [markdown]
# ## Create Node Functions
#
# Each function below represents a stage in processing a customer inquiry:
#
# 1. **categorize_inquiry**: Classifies the query into Technical, Billing, or General.
# 2. **analyze_inquiry_sentiment**: Determines if the sentiment is Positive, Neutral, or Negative.
# 3. **generate_technical_response**: Produces a response for technical issues.
# 4. **generate_billing_response**: Produces a response for billing questions.
# 5. **generate_general_response**: Produces a response for general queries.
# 6. **escalate_to_human_agent**: Escalates the query to a human if sentiment is negative.
# 7. **determine_route**: Routes the inquiry to the appropriate response node based on category and sentiment.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o", temperature=0)

# %%
def categorize_inquiry(support_state: CustomerSupportState) -> CustomerSupportState:
    """
    Classify the customer query into Technical, Billing, or General.
    """

    query = support_state["customer_query"]
    ROUTE_CATEGORY_PROMPT = """Act as a customer support agent trying to best categorize the customer query.
                               You are an agent for an AI products and hardware company.

                               Please read the customer query below and
                               determine the best category from the following list:

                               'Technical', 'Billing', or 'General'.

                               Remember:
                                - Technical queries will focus more on technical aspects like AI models, hardware, software related queries etc.
                                - General queries will focus more on general aspects like contacting support, finding things, policies etc.
                                - Billing queries will focus more on payment and purchase related aspects

                                Return just the category name (from one of the above)

                                Query:
                                {customer_query}
                            """
    prompt = ROUTE_CATEGORY_PROMPT.format(customer_query=query)
    route_category = llm.with_structured_output(QueryCategory).invoke(prompt)

    return {
        "query_category": route_category.categorized_topic
    }

# %%
categorize_inquiry({"customer_query": "Do you provide pretrained models?"})
# Out:
# {'query_category': 'Technical'}

# %%
categorize_inquiry({"customer_query": "what is your refund policy?"})
# Out:
# {'query_category': 'General'}

# %%
categorize_inquiry({"customer_query": "what payment methods are accepted?"})
# Out:
# {'query_category': 'Billing'}

# %%
def analyze_inquiry_sentiment(support_state: CustomerSupportState) -> CustomerSupportState:
    """
    Analyze the sentiment of the customer query as Positive, Neutral, or Negative.
    """

    query = support_state["customer_query"]
    SENTIMENT_CATEGORY_PROMPT = """Act as a customer support agent trying to best categorize the customer query's sentiment.
                                   You are an agent for an AI products and hardware company.

                                   Please read the customer query below,
                                   analyze its sentiment which should be one from the following list:

                                   'Positive', 'Neutral', or 'Negative'.

                                   Return just the sentiment (from one of the above)

                                   Query:
                                   {customer_query}
                                """
    prompt = SENTIMENT_CATEGORY_PROMPT.format(customer_query=query)
    sentiment_category = llm.with_structured_output(QuerySentiment).invoke(prompt)

    return {
        "query_sentiment": sentiment_category.sentiment
    }

# %%
analyze_inquiry_sentiment({"customer_query": "what is your refund policy?"})
# Out:
# {'query_sentiment': 'Neutral'}

# %%
analyze_inquiry_sentiment({"customer_query": "what is your refund policy? I am really fed up with this product and need to refund it"})
# Out:
# {'query_sentiment': 'Negative'}

# %%
from langchain_core.prompts import ChatPromptTemplate
from typing import Dict

def generate_technical_response(support_state: CustomerSupportState) -> CustomerSupportState:
    """
    Provide a technical support response by combining knowledge from the vector store and LLM.
    """
    # Retrieve category and ensure it is lowercase for metadata filtering

    categorized_topic = support_state["query_category"]
    query = support_state["customer_query"]

    # Use metadata filter for 'technical' queries
    if categorized_topic.lower() == "technical":
        metadata_filter = {"category": "technical"}
        kbase_search.search_kwargs["filter"] = metadata_filter

        # Perform retrieval from VectorDB
        relevant_docs = kbase_search.invoke(query)
        retrieved_content = "\n\n".join(doc.page_content for doc in relevant_docs)

        # Combine retrieved information into the prompt
        prompt = ChatPromptTemplate.from_template(
            """
            Craft a clear and detailed technical support response for the following customer query.
            Use the provided knowledge base information to enrich your response.
            In case there is no knowledge base information or you do not know the answer just say:

            Apologies I was not able to answer your question, please reach out to +1-xxx-xxxx

            Customer Query:
            {customer_query}

            Relevant Knowledge Base Information:
            {retrieved_content}
            """
        )

        # Generate the final response using the LLM
        chain = prompt | llm
        tech_reply = chain.invoke({
            "customer_query": query,
            "retrieved_content": retrieved_content
        }).content
    else:
        # For non-technical queries, provide a default response or a general handling
        tech_reply = "Apologies I was not able to answer your question, please reach out to +1-xxx-xxxx"

    # Update and return the modified support state
    return {
        "final_response": tech_reply
    }

# %%
generate_technical_response({"customer_query": "what is your refund policy?", "query_category": "General"})
# Out:
# {'final_response': 'Apologies I was not able to answer your question, please reach out to +1-xxx-xxxx'}

# %%
generate_technical_response({"customer_query": "do you support on-prem models?", "query_category": "Technical"})
# Out:
# {'final_response': 'Yes, we do support on-premise models. Our AI models can be deployed on-premise, and we provide comprehensive deployment guides tailored for various environments to assist you in the process. If you need further assistance or specific deployment guides, please let us know, and we will be happy to help.'}

# %%
def generate_billing_response(support_state: CustomerSupportState) -> CustomerSupportState:
    """
    Provide a billing support response by combining knowledge from the vector store and LLM.
    """
    # Retrieve category and ensure it is lowercase for metadata filtering
    categorized_topic = support_state["query_category"]
    query = support_state["customer_query"]

    # Use metadata filter for 'billing' queries
    if categorized_topic.lower() == "billing":
        metadata_filter = {"category": "billing"}
        kbase_search.search_kwargs["filter"] = metadata_filter

        # Perform retrieval from VectorDB
        relevant_docs = kbase_search.invoke(query)
        retrieved_content = "\n\n".join(doc.page_content for doc in relevant_docs)

        # Combine retrieved information into the prompt
        prompt = ChatPromptTemplate.from_template(
            """
            Craft a clear and detailed billing support response for the following customer query.
            Use the provided knowledge base information to enrich your response.
            In case there is no knowledge base information or you do not know the answer just say:

            Apologies I was not able to answer your question, please reach out to +1-xxx-xxxx

            Customer Query:
            {customer_query}

            Relevant Knowledge Base Information:
            {retrieved_content}
            """
        )

        # Generate the final response using the LLM
        chain = prompt | llm
        billing_reply = chain.invoke({
            "customer_query": query,
            "retrieved_content": retrieved_content
        }).content
    else:
        # For non-billing queries, provide a default response or a general handling
        billing_reply = "Apologies I was not able to answer your question, please reach out to +1-xxx-xxxx"

    # Update and return the modified support state
    return {
        "final_response": billing_reply
    }

# %%
generate_billing_response({"customer_query": "what payment methods are supported?", "query_category": "Billing"})
# Out:
# {'final_response': "Thank you for reaching out with your query about payment methods. We accept the following payment methods:\n\n1. **Credit Cards**: We accept all major credit cards for your convenience.\n2. **PayPal**: You can use your PayPal account to make payments securely.\n3. **Wire Transfers**: This option is available for corporate accounts.\n\nIf you have any further questions or need assistance with a specific payment method, please feel free to reach out. We're here to help!"}

# %%
def generate_general_response(support_state: CustomerSupportState) -> CustomerSupportState:
    """
    Provide a general support response by combining knowledge from the vector store and LLM.
    """
    # Retrieve category and ensure it is lowercase for metadata filtering
    categorized_topic = support_state["query_category"]
    query = support_state["customer_query"]

    # Use metadata filter for 'general' queries
    if categorized_topic.lower() == "general":
        metadata_filter = {"category": "general"}
        kbase_search.search_kwargs["filter"] = metadata_filter

        # Perform retrieval from VectorDB
        relevant_docs = kbase_search.invoke(query)
        retrieved_content = "\n\n".join(doc.page_content for doc in relevant_docs)

        # Combine retrieved information into the prompt
        prompt = ChatPromptTemplate.from_template(
            """
            Craft a clear and detailed general support response for the following customer query.
            Use the provided knowledge base information to enrich your response.
            In case there is no knowledge base information or you do not know the answer just say:

            Apologies I was not able to answer your question, please reach out to +1-xxx-xxxx

            Customer Query:
            {customer_query}

            Relevant Knowledge Base Information:
            {retrieved_content}
            """
        )

        # Generate the final response using the LLM
        chain = prompt | llm
        general_reply = chain.invoke({
            "customer_query": query,
            "retrieved_content": retrieved_content
        }).content
    else:
        # For non-general queries, provide a default response or a general handling
        general_reply = "Apologies I was not able to answer your question, please reach out to +1-xxx-xxxx"

    # Update and return the modified support state
    return {
        "final_response": general_reply
    }

# %%
generate_general_response({"customer_query": "what is your refund policy?", "query_category": "General"})
# Out:
# {'final_response': 'Thank you for reaching out with your question about our refund policy. We offer a 30-day money-back guarantee for all our products. If you wish to initiate a refund, please contact our support team, and they will assist you with the process. If you have any further questions or need additional assistance, feel free to let us know.'}

# %%
def escalate_to_human_agent(support_state: CustomerSupportState) -> CustomerSupportState:
    """
    Escalate the query to a human agent if sentiment is negative.
    """

    return {
        "final_response": "Apologies, we are really sorry! Someone from our team will be reaching out to your shortly!"
    }

# %%
def determine_route(support_state: CustomerSupportState) -> str:
    """
    Route the inquiry based on sentiment and category.
    """
    if support_state["query_sentiment"] == "Negative":
        return "escalate_to_human_agent"
    elif support_state["query_category"] == "Technical":
        return "generate_technical_response"
    elif support_state["query_category"] == "Billing":
        return "generate_billing_response"
    else:
        return "generate_general_response"

# %% [markdown]
# ## Build and Compile the Workflow
#
# We construct a LangGraph workflow with the nodes defined above:
# 1. **categorize_inquiry** → **analyze_inquiry_sentiment** → **route** to the proper response node.
# 2. If negative, escalate to a human agent.
# 3. Otherwise, produce an appropriate response (technical, billing, or general).

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import MemorySaver

# Create the graph with our typed state
customer_support_graph = StateGraph(CustomerSupportState)

# Add nodes for each function
customer_support_graph.add_node("categorize_inquiry", categorize_inquiry)
customer_support_graph.add_node("analyze_inquiry_sentiment", analyze_inquiry_sentiment)
customer_support_graph.add_node("generate_technical_response", generate_technical_response)
customer_support_graph.add_node("generate_billing_response", generate_billing_response)
customer_support_graph.add_node("generate_general_response", generate_general_response)
customer_support_graph.add_node("escalate_to_human_agent", escalate_to_human_agent)

# Add edges to represent the processing flow
customer_support_graph.add_edge("categorize_inquiry", "analyze_inquiry_sentiment")
customer_support_graph.add_conditional_edges(
    "analyze_inquiry_sentiment",
    determine_route,
    [
        "generate_technical_response",
        "generate_billing_response",
        "generate_general_response",
        "escalate_to_human_agent"
    ]
)

# All terminal nodes lead to the END
customer_support_graph.add_edge("generate_technical_response", END)
customer_support_graph.add_edge("generate_billing_response", END)
customer_support_graph.add_edge("generate_general_response", END)
customer_support_graph.add_edge("escalate_to_human_agent", END)

# Set the entry point for the workflow
customer_support_graph.set_entry_point("categorize_inquiry")

# Compile the graph into a runnable agent
memory = MemorySaver()
compiled_support_agent = customer_support_graph.compile(checkpointer=memory)

# %% [markdown]
# ## Visualize the Workflow
#
# Below is a generated diagram of the workflow using Mermaid syntax. It shows how each node connects in the graph.

# %%
from IPython.display import display, Image, Markdown

display(Image(compiled_support_agent.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Helper Function to Run the Workflow
#
# This function takes a customer query and runs it through our compiled workflow, returning the final results (category, sentiment, and generated response).

# %%
def call_support_agent(agent, prompt, user_session_id, verbose=False):
    events = agent.stream(
        {"customer_query": prompt}, # initial state of the agent
        {"configurable": {"thread_id": user_session_id}},
        stream_mode="values",
    )

    print('Running Agent. Please wait...')
    for event in events:
        if verbose:
                print(event)

    display(Markdown(event['final_response']))

# %% [markdown]
# ## Testing the Customer Support Workflow
#
# Let's test the workflow with some sample queries to verify categorization, sentiment analysis, and response generation.

# %%
[item['text'] for item in knowledge_base]
# Out:
# ['Question: How do I integrate your AI product with my existing CRM system? Answer: You can integrate our AI product with your CRM using our API. Refer to the API documentation available on our website for step-by-step guidance.',
#  'Question: What programming languages are supported by your SDK? Answer: Our SDK supports Python, Java, and JavaScript. Additional language support is planned for future updates.',
#  'Question: Can your AI models run on-premise? Answer: Yes, our AI models can be deployed on-premise. We provide deployment guides for various environments.',
#  'Question: Does your hardware support edge AI applications? Answer: Yes, our hardware is optimized for edge AI, with low-latency processing and energy-efficient designs.',
#  'Question: How do I troubleshoot issues with model performance? Answer: Start by reviewing the logs, checking resource utilization, and validating input data quality. You can also reach out to support for assistance.',
#  'Question: Can I fine-tune your AI models? Answer: Yes, our platform supports model fine-tuning using your custom datasets.',
#  'Question: What are the hardware requirements for running your AI solutions? Answer: Our AI solutions require a minimum of 16GB RAM, an Intel Core i7 processor, and an NVIDIA RTX 3060 GPU for optimal performance.',
#  'Question: Do you provide pre-trained models? Answer: Yes, we offer a range of pre-trained models for various use cases such as NLP, computer vision, and recommendation systems.',
#  'Question: How do I update the firmware on your hardware products? Answer: Firmware updates can be applied through the companion app or the firmware update tool available on our website.',
#  'Question: Is your product compatible with Kubernetes for deployment? Answer: Yes, our platform provides Kubernetes deployment templates and Helm charts for easy setup.',
#  "Question: How can I get a detailed invoice for my purchase? Answer: You can download a detailed invoice from your account dashboard under the 'Billing' section.",
#  'Question: Do you offer any discounts for annual subscriptions? Answer: Yes, we offer a 10% discount on annual subscriptions compared to monthly billing. You can select this option during checkout.',
#  'Question: Can I change my subscription plan mid-cycle? Answer: Yes, you can upgrade or downgrade your subscription plan at any time from the account dashboard. Charges will be prorated.',
#  'Question: What payment methods do you accept? Answer: We accept credit cards, PayPal, and wire transfers for corporate accounts.',
#  'Question: Do you provide refunds for unused subscription periods? Answer: Refunds are provided based on our refund policy. Please refer to our Terms and Conditions for more details.',
#  'Question: Can I receive a consolidated bill for multiple accounts? Answer: Yes, we offer consolidated billing for enterprise customers. Please contact sales to enable this feature.',
#  "Question: How do I update my billing information? Answer: You can update your billing information from the 'Billing' section in your account dashboard.",
#  'Question: Are there any additional fees apart from the subscription cost? Answer: There are no hidden fees. However, additional services like premium support may incur extra charges.',
#  'Question: Can I get a quote for budgeting purposes? Answer: Yes, you can request a custom quote by contacting our sales team.',
#  'Question: Do you charge taxes on the subscription? Answer: Applicable taxes are calculated based on your location and displayed during checkout.',
#  'Question: What are your working hours? Answer: Our support team is available from 9:00 AM to 6:00 PM, Monday to Friday.',
#  'Question: What is your refund policy? Answer: We offer a 30-day money-back guarantee for all our products. Please contact support to initiate a refund.',
#  'Question: What is your shipping policy for hardware products? Answer: We provide free shipping for orders above $500. For orders below $500, a flat shipping fee of $20 applies. Shipping typically takes 5-7 business days.',
#  'Question: How do I contact customer support? Answer: You can contact our support team via email at support@example.com or call us at 1-800-123-4567.',
#  'Question: Do you provide training for your AI products? Answer: Yes, we provide free online tutorials and offer paid instructor-led training sessions.',
#  "Question: Where can I find user manuals for your hardware products? Answer: User manuals are available on our website under the 'Support' section.",
#  'Question: Can I try your software before purchasing? Answer: Yes, we offer a 14-day free trial for our software products. Visit our website to sign up.',
#  'Question: How do I escalate an unresolved issue? Answer: You can escalate unresolved issues by emailing our escalation team at escalations@example.com.',
#  'Question: Do you have a reseller program? Answer: Yes, we have a reseller program. Please contact our sales team for details.',
#  'Question: What is your policy for handling damaged hardware deliveries? Answer: If you receive damaged hardware, please report it within 48 hours to our support team. We will arrange for a replacement.']

# %%
uid = 'jim001'
query = "do you support pre-trained models?"
call_support_agent(agent=compiled_support_agent,
                   prompt=query,
                   user_session_id=uid,
                   verbose=True)
# Out:
# Running Agent. Please wait...
# {'customer_query': 'do you support pre-trained models?'}
# {'customer_query': 'do you support pre-trained models?', 'query_category': 'Technical'}
# {'customer_query': 'do you support pre-trained models?', 'query_category': 'Technical', 'query_sentiment': 'Neutral'}
# {'customer_query': 'do you support pre-trained models?', 'query_category': 'Technical', 'query_sentiment': 'Neutral', 'final_response': 'Yes, we do support pre-trained models. We offer a range of pre-trained models tailored for various use cases, including natural language processing (NLP), computer vision, and recommendation systems. These models are designed to help you accelerate your development process by leveraging existing, well-trained models that can be fine-tuned or used as-is for your specific applications. If you have any further questions or need assistance in selecting the right model for your needs, please feel free to reach out.'}
# Yes, we do support pre-trained models. We offer a range of pre-trained models tailored for various use cases, including natural language processing (NLP), computer vision, and recommendation systems. These models are designed to help you accelerate your development process by leveraging existing, well-trained models that can be fine-tuned or used as-is for your specific applications. If you have any further questions or need assistance in selecting the right model for your needs, please feel free to reach out.

# %%
query = "how do I get my invoice?"
call_support_agent(agent=compiled_support_agent,
                   prompt=query,
                   user_session_id=uid,
                   verbose=True)
# Out:
# Running Agent. Please wait...
# {'customer_query': 'how do I get my invoice?', 'query_category': 'Technical', 'query_sentiment': 'Neutral', 'final_response': 'Yes, we do support pre-trained models. We offer a range of pre-trained models tailored for various use cases, including natural language processing (NLP), computer vision, and recommendation systems. These models are designed to help you accelerate your development process by leveraging existing, well-trained models that can be fine-tuned or used as-is for your specific applications. If you have any further questions or need assistance in selecting the right model for your needs, please feel free to reach out.'}
# {'customer_query': 'how do I get my invoice?', 'query_category': 'Billing', 'query_sentiment': 'Neutral', 'final_response': 'Yes, we do support pre-trained models. We offer a range of pre-trained models tailored for various use cases, including natural language processing (NLP), computer vision, and recommendation systems. These models are designed to help you accelerate your development process by leveraging existing, well-trained models that can be fine-tuned or used as-is for your specific applications. If you have any further questions or need assistance in selecting the right model for your needs, please feel free to reach out.'}
# {'customer_query': 'how do I get my invoice?', 'query_category': 'Billing', 'query_sentiment': 'Neutral', 'final_response': 'Yes, we do support pre-trained models. We offer a range of pre-trained models tailored for various use cases, including natural language processing (NLP), computer vision, and recommendation systems. These models are designed to help you accelerate your development process by leveraging existing, well-trained models that can be fine-tuned or used as-is for your specific applications. If you have any further questions or need assistance in selecting the right model for your needs, please feel free to reach out.'}
# {'customer_query': 'how do I get my invoice?', 'query_category': 'Billing', 'query_sentiment': 'Neutral', 'final_response': "Thank you for reaching out with your query about obtaining your invoice. You can easily download a detailed invoice by accessing your account dashboard. Once you're logged in, navigate to the 'Billing' section where you will find the option to download your invoice. If you encounter any issues or need further assistance, please feel free to reach out."}
# Thank you for reaching out with your query about obtaining your invoice. You can easily download a detailed invoice by accessing your account dashboard. Once you're logged in, navigate to the 'Billing' section where you will find the option to download your invoice. If you encounter any issues or need further assistance, please feel free to reach out.

# %%
query = "Can you tell me about your shipping policy?"
call_support_agent(agent=compiled_support_agent,
                   prompt=query,
                   user_session_id=uid,
                   verbose=False)
# Out:
# Running Agent. Please wait...
# Thank you for reaching out with your query about our shipping policy. For hardware products, we offer free shipping on orders that total over $500. If your order is below $500, a flat shipping fee of $20 will be applied. Typically, shipping takes between 5 to 7 business days. If you have any further questions or need additional assistance, please feel free to ask!

# %%
query = "I'm fed up with this faulty hardware, I need a refund"
call_support_agent(agent=compiled_support_agent,
                   prompt=query,
                   user_session_id=uid,
                   verbose=True)
# Out:
# Running Agent. Please wait...
# {'customer_query': "I'm fed up with this faulty hardware, I need a refund", 'query_category': 'General', 'query_sentiment': 'Neutral', 'final_response': 'Thank you for reaching out with your query about our shipping policy. For hardware products, we offer free shipping on orders that total over $500. If your order is below $500, a flat shipping fee of $20 will be applied. Typically, shipping takes between 5 to 7 business days. If you have any further questions or need additional assistance, please feel free to ask!'}
# {'customer_query': "I'm fed up with this faulty hardware, I need a refund", 'query_category': 'Billing', 'query_sentiment': 'Neutral', 'final_response': 'Thank you for reaching out with your query about our shipping policy. For hardware products, we offer free shipping on orders that total over $500. If your order is below $500, a flat shipping fee of $20 will be applied. Typically, shipping takes between 5 to 7 business days. If you have any further questions or need additional assistance, please feel free to ask!'}
# {'customer_query': "I'm fed up with this faulty hardware, I need a refund", 'query_category': 'Billing', 'query_sentiment': 'Negative', 'final_response': 'Thank you for reaching out with your query about our shipping policy. For hardware products, we offer free shipping on orders that total over $500. If your order is below $500, a flat shipping fee of $20 will be applied. Typically, shipping takes between 5 to 7 business days. If you have any further questions or need additional assistance, please feel free to ask!'}
# {'customer_query': "I'm fed up with this faulty hardware, I need a refund", 'query_category': 'Billing', 'query_sentiment': 'Negative', 'final_response': 'Apologies, we are really sorry! Someone from our team will be reaching out to your shortly!'}
# Apologies, we are really sorry! Someone from our team will be reaching out to your shortly!

# %%
query = "What are your working hours?"
call_support_agent(agent=compiled_support_agent,
                   prompt=query,
                   user_session_id=uid,
                   verbose=True)
# Out:
# Running Agent. Please wait...
# {'customer_query': 'What are your working hours?', 'query_category': 'Billing', 'query_sentiment': 'Negative', 'final_response': 'Apologies, we are really sorry! Someone from our team will be reaching out to your shortly!'}
# {'customer_query': 'What are your working hours?', 'query_category': 'General', 'query_sentiment': 'Negative', 'final_response': 'Apologies, we are really sorry! Someone from our team will be reaching out to your shortly!'}
# {'customer_query': 'What are your working hours?', 'query_category': 'General', 'query_sentiment': 'Neutral', 'final_response': 'Apologies, we are really sorry! Someone from our team will be reaching out to your shortly!'}
# {'customer_query': 'What are your working hours?', 'query_category': 'General', 'query_sentiment': 'Neutral', 'final_response': 'Thank you for reaching out with your query. Our support team is available to assist you from 9:00 AM to 6:00 PM, Monday to Friday. If you have any further questions or need assistance during these hours, please feel free to contact us.'}
# Thank you for reaching out with your query. Our support team is available to assist you from 9:00 AM to 6:00 PM, Monday to Friday. If you have any further questions or need assistance during these hours, please feel free to contact us.
