# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")
hist = ticker.history(period="5d")

print("Last 5 days of AAPL data:")
print(hist[["Open", "High", "Low", "Close", "Volume"]])
# Out:
# Last 5 days of AAPL data:
#                                  Open        High         Low       Close  \
# Date
# 2026-02-10 00:00:00-05:00  274.890015  275.369995  272.940002  273.679993
# 2026-02-11 00:00:00-05:00  274.700012  280.179993  274.450012  275.500000
# 2026-02-12 00:00:00-05:00  275.589996  275.720001  260.179993  261.730011
# 2026-02-13 00:00:00-05:00  262.010010  262.230011  255.449997  255.779999
# 2026-02-17 00:00:00-05:00  258.049988  266.290009  255.539993  263.880005
#
#                              Volume
# Date
# 2026-02-10 00:00:00-05:00  34376900
# 2026-02-11 00:00:00-05:00  51931300
# 2026-02-12 00:00:00-05:00  81077200
# 2026-02-13 00:00:00-05:00  56290700
# 2026-02-17 00:00:00-05:00  58392700
